# %%
#列表方法
#append
t=['a','b','c']
t.append('d')
print(t)
# Out:
# ['a', 'b', 'c', 'd']

# %%
#extend方法接收一个列表作为参数，并将所有元素附加到列表中
t1=['a','b','c']
t2=['d','e']
t1.extend(t2)
print(t1)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
#sort方法排序
t=['d','e','b','a','c']
t.sort()
print(t)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
#列表的方法都是无返回值的，他们修改列表，并返回None
t=t.sort()
print(t)
# Out:
# None

# %%
#如果想把列表中的所有元素加起来可以使用下面的循环
def add_all(t):
    total=0
    for x in t:
        total+=x
    return tatal

# %%
t=[1,2,3]
type(t)
t[:0]
# Out:
# []

# %%
sum(t[:2])
# Out:
# 3

# %%
#练习：编写一个函数nested_sum,接收一个由内嵌的整数列表组成的列表为形参，并将内嵌列表中的值全部加起来
def nested_sum(t):
    total=0
    for x in t:
        if type(x)==int:
            total+=x
        elif type(x)==list:
            total+=sum(x)
    return total
a=[1,2,3,[4,5]]
nested_sum(a)
# Out:
# 15

# %%
def capitalize_all(t):
    res=[]
    for s in t:
        res.append(s.capitalize())#str.capitalize()返回字符串副本，其首字母大写，其余小写
    return res
t=['heLlo','apple']
capitalize_all(t)
# Out:
# ['Hello', 'Apple']

# %%
#练习：使用capitalize_all来编写一个函数capitalize_nested,
#接收一个由内嵌的字符串列表组成的列表作为形参，并返回一个新列表，其元素为内嵌的大写字符串列表
def capitalize_nested(t):
    res1=[]
    for s in t:
        if type(s)==str:
            res1.append(s.capitalize())
        elif type(s)==list:
            res1.append(capitalize_all(s))
    return res1
t1=[['hello','apple'],['banana','orange']]
capitalize_nested(t1)
# Out:
# [['Hello', 'Apple'], ['Banana', 'Orange']]

# %%
def only_upper(t):
    res=[]
    for s in t:
        if s.isupper():
            res.append(s)
    return res
t=['heloo','Hello','HELLO']
only_upper(t)
# Out:
# ['HELLO']

# %%
#练习：编写一个函数，接收一个数字列表，并返回其累积和
def cumulative_sum(t):
    res=[]
    for i in range(len(t)):
        res.append(sum(t[:(i+1)]))
    return res
t=[1,2,3]
cumulative_sum(t)
# Out:
# [1, 3, 6]

# %%
#删除元素
t=['a','b','c']
x=t.pop(1)
print(t)
# Out:
# ['a', 'c']

# %%
t.pop()
# Out:
# 'c'

# %%
t=['a','b','c']
del t[1]

# %%
print(t)
# Out:
# ['a', 'c']

# %%
t=['a','b','c']
t.remove('b')
print(t)
# Out:
# ['a', 'c']

# %%
t=['a','b','c','d','e']
del t[1:4]
print(t)
# Out:
# ['a', 'e']

# %%
#练习：编写一个函数middle，接收一个列表作为形参，并返回一个新列表，包含除了第一个和最后一个元素之外的所有元素
def middle(t):
    del t[0]
    del t[-1]
    return t
t=[1,2,3,4]
middle(t)
# Out:
# [2, 3]

# %%
def chop(t):
    del t[0]
    del t[-1]
    return None
t=[1,2,3,4]
chop(t)

# %%
s='spam'
list(s)
# Out:
# ['s', 'p', 'a', 'm']

# %%
#如果想要将字符串拆成单词，可以使用split
s='pining for the fjords'
t=s.split()
print(t)
# Out:
# ['pining', 'for', 'the', 'fjords']

# %%
s='spam-spam-spam'
s.split('-')
# Out:
# ['spam', 'spam', 'spam']

# %%
#join是split的逆操作，它接收字符串列表并拼接每个元素。join是字符串方法，所以必须在分隔符上调用它，并传入列表作为实参
t=['pining','for','the','fjords']
delimiter=' '
delimiter.join(t)
# Out:
# 'pining for the fjords'

# %%
#对象和值
a='banana'
b='banana'
a is b
# Out:
# True

# %%
a=[1,2,3]
b=[1,2,3]
a is b
# Out:
# False

# %%
#别名：一个对象有多个不同名称的引用
a=[1,2,3]
b=a
b is a
# Out:
# True

# %%
b[0]=17
print(a)
# Out:
# [17, 2, 3]

# %%
#列表参数
def delete_head(t):
    del t[0]
letters=['a','b','c']
delete_head(letters)
print(letters)
# Out:
# ['b', 'c']

# %%
#区分修改列表和新建列表的操作十分重要，append修改，“+”是新建
t1=[1,2]
t2=t1.append(3)
print(t1)
# Out:
# [1, 2, 3]

# %%
print(t2)
# Out:
# None

# %%
t3=t1+[4]
print(t3)
# Out:
# [1, 2, 3, 4]

# %%
def bad_delete_head(t):
    t=t[1:]
bad_delete_head(t3)

# %%
def tail(t):
    return t[1:]
letters=['a','b','c']
rest=tail(letters)
print(rest)
# Out:
# ['b', 'c']

# %%
print(letters)
# Out:
# ['a', 'b', 'c']

# %%
#练习：编写一个函数is_sorted,接收一个列表作为形参，并当列表是按照升序排好序时返回True，否则False
def is_sorted(t):
    for i in range(len(t)-1):
        if t[i]>t[i+1]:
            return False
    return True
t=[1,2,2]
is_sorted(t)
# Out:
# True

# %%
#练习：编写一个函数is_anagram,接收两个字符串，当它们互为回文时返回True
def is_anagram(word1,word2):
    if word1.sorted()==word2:
        return True
    return False
is_anagram('ab','ba')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-85d6d5401dcc> in <module>
#       4         return True
#       5     return False
# ----> 6 is_anagram('ab','ba')
#
# <ipython-input-37-85d6d5401dcc> in is_anagram(word1, word2)
#       1 #练习：编写一个函数is_anagram,接收两个字符串，当它们互为回文时返回True
#       2 def is_anagram(word1,word2):
# ----> 3     if word1.sorted()==word2:
#       4         return True
#       5     return False
#
# AttributeError: 'str' object has no attribute 'sorted'

# %%
def is_anagram(word1,word2):
    if word1.sort()==word2:
        return True
    return False
is_anagram('ab','ba')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-18c667a46b0c> in <module>
#       3         return True
#       4     return False
# ----> 5 is_anagram('ab','ba')
#
# <ipython-input-38-18c667a46b0c> in is_anagram(word1, word2)
#       1 def is_anagram(word1,word2):
# ----> 2     if word1.sort()==word2:
#       3         return True
#       4     return False
#       5 is_anagram('ab','ba')
#
# AttributeError: 'str' object has no attribute 'sort'

# %%
def is_anagram(word1,word2):
    if "".join(list(word1).sort())==word2 or "".join(list(word2).sort())==word1:
        return True
    return False
is_anagram('hello','ab')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-716276a7e28b> in <module>
#       3         return True
#       4     return False
# ----> 5 is_anagram('hello','ab')
#
# <ipython-input-39-716276a7e28b> in is_anagram(word1, word2)
#       1 def is_anagram(word1,word2):
# ----> 2     if "".join(list(word1).sort())==word2 or "".join(list(word2).sort())==word1:
#       3         return True
#       4     return False
#       5 is_anagram('hello','ab')
#
# TypeError: can only join an iterable

# %%
word1='hello'
t=list(word1)
print(t)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
sorted(t)
# Out:
# ['e', 'h', 'l', 'l', 'o']

# %%
print(t)
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
def is_anagram(word1,word2):
    if "".join(sorted(list(word1)))==word2 or "".join(sorted(list(word2)))==word1:
        return True
    return False
is_anagram('hello','ello')
# Out:
# False

# %%
#练习：生日悖论
#编写一个函数has_duplicates接收一个列表，当其中任何一个元素出现多于一次时，返回True.它不应当修改原始列表
def has_duplicates(t):
    for s in t:
        if t.count(s)>1:
            return True 
    return False
t=[1,3,2]
has_duplicates(t)
# Out:
# False

# %%
def has_duplicates1(t):
    new_t=t[:] #生成新的列表
    new_t.sort() #因为这个会修改列表，不会生成新的列表
    for i in range(len(new_t)-1):
        if new_t[i]==new_t[i+1]:
            return True
    return False
t=[1,3,3]
has_duplicates1(t)
# Out:
# True

# %%
#如果你们班级中有23个学生，那么其中有两人生日相同的几率有多大？
import random
random.randint(1,365)
# Out:
# 275

# %%
def random_birt(students):
    t=[]
    for i in range(students):
        t.append(random.randint(1,366))
    return t
# random_birt(23)
        
def count_match(students,numbers):
    t=random_birt(students)
    count=0
    for i in range(numbers):
        if has_duplicates(t):
            count+=1
    return count
count_match(23,1000)
# Out:
# 0

# %%
def random_birt(students):
    t=[]
    for i in range(students):
        t.append(random.randint(1,366))
    return t
# random_birt(23)
        
def count_match(students,numbers):
    
    count=0
    for i in range(numbers):
        t=random_birt(students)
        if has_duplicates(t):
            count+=1
    return count
count_match(23,1000)
# Out:
# 513

# %%
#练习：编写一个函数remove_dumplicates,接收一个列表，并返回一个新列表，其中质保函原始列表的每个元素的唯一一份。提示：顺序不需要相同
def remove_dumplicates(t):
    new_t=[]
    for i in range(len(t)):
        if t[i] not in new_t:
            new_t.append(t[i])
    return new_t
t=[1,[1,2],[2,1]]
remove_dumplicates(t)
# Out:
# [1, [1, 2], [2, 1]]

# %%
#练习：读取文件words.txt,生成一个列表，比较append和t=t+[x]方法的运行时长
import time
def read_words():
    fin=open('words.txt')
    t=[]
    for line in fin:
        word=line.strip()
        t.append(word)
    return t
start_time=time.time()
t=read_words()
elapsed_time=time.time()-start_time
print(len(t))
print(t[:10])
print(elapsed_time)
# Out:
# 113809
# ['aa', 'aah', 'aahed', 'aahing', 'aahs', 'aal', 'aalii', 'aaliis', 'aals', 'aardvark']
# 0.09674572944641113

# %%
def read_words1():
    fin=open('words.txt')
    t=[]
    for line in fin:
        word=line.strip()
        t=t+[word]
    return t
start_time=time.time()
t=read_words1()
elapsed_time=time.time()-start_time
print(len(t))
print(t[:10])
print(elapsed_time)

# %%
#练习：编写一个函数bisect,接收一个排好序的列表，以及一个目标值，当目标值在列表之中，返回其下标，否则None
def bisect(t,target):
    for i in range(len(t)):
        if t[i]==target:
            return i
    return None
t=[1,2,3,4,5,6]
bisect(t,5)
# Out:
# 4

# %%
t=[1,2,3]
t.find(1)
#想直接用用find方法，结果不行
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-36895259f80e> in <module>
#       1 t=[1,2,3]
# ----> 2 t.find(1)
#       3 #想直接用用find方法，结果不行
#
# AttributeError: 'list' object has no attribute 'find'

# %%
import bisect
def find_lt(a,x):
    i=bisect.bisect_left(a,x)
    if i != len(a) and a[i]==x:
        return i
    return None
t=read_words()
find_lt(t,'hello')
# Out:
# 45100

# %%
#练习：编写一个程序找到单词表中互为倒序的单词对
def remove_dumplicates(t):
    new_t=[]
    for i in range(len(t)):
        if t[i] not in new_t:
            new_t.append(t[i])
    return new_t
# t=[1,[1,2],[2,1]]
# remove_dumplicates(t)
def daoxu():
    a=[]
    t=read_words()
    for s in t:
        if s[::-1] in t:
            a.append(sorted([s,s[::-1]]))
    return a
daoxu()

# %%
import bisect
def remove_dumplicates(t):
    new_t=[]
    for i in range(len(t)):
        if t[i] not in new_t:
            new_t.append(t[i])
    return new_t

def find_lt(a,x):
    i=bisect.bisect_left(a,x)
    if i != len(a) and a[i]==x:
        return True
    return None
def daoxu():
    a=[]
    t=read_words()
    for s in t:
        if find_lt(t,s[::-1])==True and s!=s[::-1]:
            a.append(sorted([s,s[::-1]]))
    return remove_dumplicates(a)
daoxu()
# Out:
# [['abut', 'tuba'],
#  ['ad', 'da'],
#  ['ados', 'soda'],
#  ['agar', 'raga'],
#  ['agas', 'saga'],
#  ['agenes', 'senega'],
#  ['ah', 'ha'],
#  ['aider', 'redia'],
#  ['airts', 'stria'],
#  ['ajar', 'raja'],
#  ['alif', 'fila'],
#  ['am', 'ma'],
#  ['amen', 'nema'],
#  ['amis', 'sima'],
#  ['an', 'na'],
#  ['anger', 'regna'],
#  ['animal', 'lamina'],
#  ['animes', 'semina'],
#  ['anon', 'nona'],
#  ['ante', 'etna'],
#  ['are', 'era'],
#  ['ares', 'sera'],
#  ['aril', 'lira'],
#  ['arris', 'sirra'],
#  ['arum', 'mura'],
#  ['at', 'ta'],
#  ['ate', 'eta'],
#  ['ates', 'seta'],
#  ['auks', 'skua'],
#  ['avid', 'diva'],
#  ['avo', 'ova'],
#  ['ay', 'ya'],
#  ['bad', 'dab'],
#  ['bag', 'gab'],
#  ['bal', 'lab'],
#  ['bals', 'slab'],
#  ['ban', 'nab'],
#  ['bard', 'drab'],
#  ['bas', 'sab'],
#  ['bat', 'tab'],
#  ['bats', 'stab'],
#  ['bed', 'deb'],
#  ['ben', 'neb'],
#  ['bid', 'dib'],
#  ['big', 'gib'],
#  ['bin', 'nib'],
#  ['bins', 'snib'],
#  ['bird', 'drib'],
#  ['bis', 'sib'],
#  ['bog', 'gob'],
#  ['bos', 'sob'],
#  ['bots', 'stob'],
#  ['bows', 'swob'],
#  ['brad', 'darb'],
#  ['brag', 'garb'],
#  ['bud', 'dub'],
#  ['bun', 'nub'],
#  ['buns', 'snub'],
#  ['bur', 'rub'],
#  ['burd', 'drub'],
#  ['burg', 'grub'],
#  ['bus', 'sub'],
#  ['but', 'tub'],
#  ['buts', 'stub'],
#  ['cam', 'mac'],
#  ['cap', 'pac'],
#  ['cares', 'serac'],
#  ['cod', 'doc'],
#  ['cram', 'marc'],
#  ['cud', 'duc'],
#  ['dag', 'gad'],
#  ['dah', 'had'],
#  ['dahs', 'shad'],
#  ['dam', 'mad'],
#  ['dap', 'pad'],
#  ['dart', 'trad'],
#  ['daw', 'wad'],
#  ['debut', 'tubed'],
#  ['decal', 'laced'],
#  ['dedal', 'laded'],
#  ['deem', 'meed'],
#  ['deep', 'peed'],
#  ['deeps', 'speed'],
#  ['deer', 'reed'],
#  ['dees', 'seed'],
#  ['defer', 'refed'],
#  ['degami', 'imaged'],
#  ['deifier', 'reified'],
#  ['deil', 'lied'],
#  ['deke', 'eked'],
#  ['del', 'led'],
#  ['delf', 'fled'],
#  ['deliver', 'reviled'],
#  ['dels', 'sled'],
#  ['demit', 'timed'],
#  ['denier', 'reined'],
#  ['denies', 'seined'],
#  ['denim', 'mined'],
#  ['dens', 'sned'],
#  ['depot', 'toped'],
#  ['depots', 'stoped'],
#  ['derat', 'tared'],
#  ['derats', 'stared'],
#  ['dessert', 'tressed'],
#  ['desserts', 'stressed'],
#  ['devas', 'saved'],
#  ['devil', 'lived'],
#  ['dew', 'wed'],
#  ['dewans', 'snawed'],
#  ['dexes', 'sexed'],
#  ['dial', 'laid'],
#  ['dialer', 'relaid'],
#  ['diaper', 'repaid'],
#  ['dig', 'gid'],
#  ['dim', 'mid'],
#  ['dinar', 'ranid'],
#  ['diols', 'sloid'],
#  ['dirts', 'strid'],
#  ['do', 'od'],
#  ['dog', 'god'],
#  ['dom', 'mod'],
#  ['don', 'nod'],
#  ['doom', 'mood'],
#  ['door', 'rood'],
#  ['dor', 'rod'],
#  ['dormin', 'nimrod'],
#  ['dorp', 'prod'],
#  ['dos', 'sod'],
#  ['dot', 'tod'],
#  ['drail', 'liard'],
#  ['draw', 'ward'],
#  ['drawer', 'reward'],
#  ['draws', 'sward'],
#  ['dray', 'yard'],
#  ['dual', 'laud'],
#  ['ducs', 'scud'],
#  ['duel', 'leud'],
#  ['duo', 'oud'],
#  ['dup', 'pud'],
#  ['dups', 'spud'],
#  ['eat', 'tae'],
#  ['edile', 'elide'],
#  ['edit', 'tide'],
#  ['eel', 'lee'],
#  ['eh', 'he'],
#  ['elides', 'sedile'],
#  ['em', 'me'],
#  ['emes', 'seme'],
#  ['emir', 'rime'],
#  ['emit', 'time'],
#  ['emits', 'stime'],
#  ['enol', 'lone'],
#  ['er', 're'],
#  ['ergo', 'ogre'],
#  ['eros', 'sore'],
#  ['ervil', 'livre'],
#  ['etas', 'sate'],
#  ['even', 'neve'],
#  ['evil', 'live'],
#  ['eviler', 'relive'],
#  ['fer', 'ref'],
#  ['fires', 'serif'],
#  ['flog', 'golf'],
#  ['flow', 'wolf'],
#  ['fool', 'loof'],
#  ['gal', 'lag'],
#  ['gals', 'slag'],
#  ['gam', 'mag'],
#  ['gan', 'nag'],
#  ['gar', 'rag'],
#  ['gas', 'sag'],
#  ['gat', 'tag'],
#  ['gats', 'stag'],
#  ['gel', 'leg'],
#  ['gelder', 'redleg'],
#  ['get', 'teg'],
#  ['gip', 'pig'],
#  ['girt', 'trig'],
#  ['gnar', 'rang'],
#  ['gnat', 'tang'],
#  ['gnats', 'stang'],
#  ['gnaws', 'swang'],
#  ['gnus', 'sung'],
#  ['got', 'tog'],
#  ['gul', 'lug'],
#  ['gulp', 'plug'],
#  ['guls', 'slug'],
#  ['gum', 'mug'],
#  ['gums', 'smug'],
#  ['guns', 'snug'],
#  ['gut', 'tug'],
#  ['habus', 'subah'],
#  ['hahs', 'shah'],
#  ['hales', 'selah'],
#  ['hap', 'pah'],
#  ['hay', 'yah'],
#  ['hey', 'yeh'],
#  ['ho', 'oh'],
#  ['hoop', 'pooh'],
#  ['hop', 'poh'],
#  ['is', 'si'],
#  ['it', 'ti'],
#  ['jar', 'raj'],
#  ['kay', 'yak'],
#  ['keel', 'leek'],
#  ['keels', 'sleek'],
#  ['keep', 'peek'],
#  ['keets', 'steek'],
#  ['kips', 'spik'],
#  ['knaps', 'spank'],
#  ['knar', 'rank'],
#  ['knits', 'stink'],
#  ['lager', 'regal'],
#  ['lair', 'rial'],
#  ['lap', 'pal'],
#  ['lares', 'seral'],
#  ['larum', 'mural'],
#  ['las', 'sal'],
#  ['leer', 'reel'],
#  ['lees', 'seel'],
#  ['leets', 'steel'],
#  ['leper', 'repel'],
#  ['lever', 'revel'],
#  ['levins', 'snivel'],
#  ['liar', 'rail'],
#  ['lin', 'nil'],
#  ['lion', 'noil'],
#  ['lit', 'til'],
#  ['lobo', 'obol'],
#  ['loom', 'mool'],
#  ['loons', 'snool'],
#  ['loop', 'pool'],
#  ['loops', 'spool'],
#  ['loot', 'tool'],
#  ['looter', 'retool'],
#  ['loots', 'stool'],
#  ['lop', 'pol'],
#  ['lotos', 'sotol'],
#  ['macs', 'scam'],
#  ['maes', 'seam'],
#  ['map', 'pam'],
#  ['mar', 'ram'],
#  ['marcs', 'scram'],
#  ['mart', 'tram'],
#  ['mat', 'tam'],
#  ['maws', 'swam'],
#  ['may', 'yam'],
#  ['meet', 'teem'],
#  ['meter', 'retem'],
#  ['mho', 'ohm'],
#  ['mils', 'slim'],
#  ['mir', 'rim'],
#  ['mis', 'sim'],
#  ['mon', 'nom'],
#  ['moor', 'room'],
#  ['moot', 'toom'],
#  ['mot', 'tom'],
#  ['mures', 'serum'],
#  ['mus', 'sum'],
#  ['muts', 'stum'],
#  ['namer', 'reman'],
#  ['nap', 'pan'],
#  ['naps', 'span'],
#  ['neep', 'peen'],
#  ['net', 'ten'],
#  ['neves', 'seven'],
#  ['new', 'wen'],
#  ['nip', 'pin'],
#  ['nips', 'spin'],
#  ['nit', 'tin'],
#  ['no', 'on'],
#  ['nolos', 'solon'],
#  ['nos', 'son'],
#  ['not', 'ton'],
#  ['notes', 'seton'],
#  ['now', 'won'],
#  ['nu', 'un'],
#  ['nus', 'sun'],
#  ['nut', 'tun'],
#  ['nuts', 'stun'],
#  ['oat', 'tao'],
#  ['oohs', 'shoo'],
#  ['oot', 'too'],
#  ['os', 'so'],
#  ['ow', 'wo'],
#  ['pacer', 'recap'],
#  ['pals', 'slap'],
#  ['pans', 'snap'],
#  ['par', 'rap'],
#  ['part', 'trap'],
#  ['parts', 'strap'],
#  ['pas', 'sap'],
#  ['pat', 'tap'],
#  ['paw', 'wap'],
#  ['paws', 'swap'],
#  ['pay', 'yap'],
#  ['peels', 'sleep'],
#  ['pees', 'seep'],
#  ['per', 'rep'],
#  ['pets', 'step'],
#  ['pins', 'snip'],
#  ['pis', 'sip'],
#  ['pit', 'tip'],
#  ['pols', 'slop'],
#  ['pools', 'sloop'],
#  ['poons', 'snoop'],
#  ['port', 'trop'],
#  ['ports', 'strop'],
#  ['pot', 'top'],
#  ['pots', 'stop'],
#  ['pow', 'wop'],
#  ['pows', 'swop'],
#  ['prat', 'tarp'],
#  ['pupils', 'slipup'],
#  ['puris', 'sirup'],
#  ['pus', 'sup'],
#  ['put', 'tup'],
#  ['raps', 'spar'],
#  ['rat', 'tar'],
#  ['rats', 'star'],
#  ['raw', 'war'],
#  ['ray', 'yar'],
#  ['rebus', 'suber'],
#  ['rebut', 'tuber'],
#  ['recaps', 'spacer'],
#  ['redes', 'seder'],
#  ['redips', 'spider'],
#  ['redraw', 'warder'],
#  ['redrawer', 'rewarder'],
#  ['rees', 'seer'],
#  ['reflet', 'telfer'],
#  ['reflow', 'wolfer'],
#  ['reknit', 'tinker'],
#  ['reknits', 'stinker'],
#  ['relit', 'tiler'],
#  ['remeet', 'teemer'],
#  ['remit', 'timer'],
#  ['rennet', 'tenner'],
#  ['repins', 'sniper'],
#  ['res', 'ser'],
#  ['rot', 'tor'],
#  ['sallets', 'stellas'],
#  ['saps', 'spas'],
#  ['sat', 'tas'],
#  ['saw', 'was'],
#  ['scares', 'seracs'],
#  ['secret', 'terces'],
#  ['seeks', 'skees'],
#  ['selahs', 'shales'],
#  ['sirs', 'sris'],
#  ['sit', 'tis'],
#  ['six', 'xis'],
#  ['skeets', 'steeks'],
#  ['skips', 'spiks'],
#  ['sleeps', 'speels'],
#  ['sleets', 'steels'],
#  ['slit', 'tils'],
#  ['sloops', 'spools'],
#  ['smart', 'trams'],
#  ['smuts', 'stums'],
#  ['snaps', 'spans'],
#  ['snaw', 'wans'],
#  ['snaws', 'swans'],
#  ['snips', 'spins'],
#  ['snit', 'tins'],
#  ['snoops', 'spoons'],
#  ['snoot', 'toons'],
#  ['snot', 'tons'],
#  ['snow', 'wons'],
#  ['sow', 'wos'],
#  ['spat', 'taps'],
#  ['spay', 'yaps'],
#  ['spirt', 'trips'],
#  ['spirts', 'strips'],
#  ['spit', 'tips'],
#  ['sports', 'strops'],
#  ['spot', 'tops'],
#  ['spots', 'stops'],
#  ['sprat', 'tarps'],
#  ['sprits', 'stirps'],
#  ['staw', 'wats'],
#  ['stew', 'wets'],
#  ['stow', 'wots'],
#  ['stows', 'swots'],
#  ['straw', 'warts'],
#  ['strow', 'worts'],
#  ['struts', 'sturts'],
#  ['swat', 'taws'],
#  ['sway', 'yaws'],
#  ['swot', 'tows'],
#  ['tav', 'vat'],
#  ['taw', 'wat'],
#  ['tew', 'wet'],
#  ['tort', 'trot'],
#  ['tow', 'wot'],
#  ['trow', 'wort'],
#  ['way', 'yaw']]

# %%
#练习：编写一个程序找到单词表中所有互锁的单词
#互锁：两个单词，从每个单词中交错去除一个字母可以组成一个新的单词，我们称之为互锁，例如shoe和code可以互锁为schooled
def husuo():
    a=[]
    t=read_words()
    for s in t:
        s1=[]
        s2=[]
        for i in range(len(s)):
            
            if i%2!=0:
                s1.append(s[i])
            elif i%2==0:
                s2.append(s[i])
        word1=''.join(s1)
        word2=''.join(s2)
        if find_lt(t,word1) and find_lt(t,word2):
            a.append([word1,word2])
    return a
husuo()
# Out:
# [['as', 'ah'],
#  ['be', 'aby'],
#  ['be', 'aid'],
#  ['be', 'ais'],
#  ['bi', 'ar'],
#  ['bi', 'ars'],
#  ['be', 'ay'],
#  ['be', 'ays'],
#  ['cos', 'ars'],
#  ['de', 'add'],
#  ['do', 'ais'],
#  ['don', 'anus'],
#  ['dit', 'arf'],
#  ['doty', 'aril'],
#  ['fed', 'ail'],
#  ['fet', 'are'],
#  ['fet', 'ares'],
#  ['go', 'ai'],
#  ['go', 'ais'],
#  ['gem', 'ala'],
#  ['gal', 'ani'],
#  ['gal', 'anis'],
#  ['gae', 'ant'],
#  ['gae', 'ants'],
#  ['gae', 'arf'],
#  ['gain', 'arras'],
#  ['ged', 'are'],
#  ['is', 'ad'],
#  ['is', 'am'],
#  ['is', 'an'],
#  ['in', 'ar'],
#  ['in', 'ars'],
#  ['is', 'ar'],
#  ['it', 'ar'],
#  ['it', 'ars'],
#  ['is', 'at'],
#  ['la', 'age'],
#  ['la', 'ais'],
#  ['lee', 'aine'],
#  ['lees', 'aine'],
#  ['lee', 'all'],
#  ['lee', 'alls'],
#  ['lid', 'ale'],
#  ['lis', 'ale'],
#  ['lo', 'alt'],
#  ['la', 'am'],
#  ['lie', 'ask'],
#  ['lie', 'asks'],
#  ['lo', 'as'],
#  ['lo', 'at'],
#  ['ma', 'ai'],
#  ['ma', 'ais'],
#  ['me', 'ai'],
#  ['me', 'ais'],
#  ['mi', 'ana'],
#  ['met', 'area'],
#  ['no', 'ain'],
#  ['nos', 'ain'],
#  ['na', 'an'],
#  ['nae', 'ants'],
#  ['no', 'any'],
#  ['nos', 'any'],
#  ['na', 'as'],
#  ['na', 'at'],
#  ['na', 'ate'],
#  ['pa', 'ain'],
#  ['pay', 'air'],
#  ['pie', 'alt'],
#  ['pie', 'alts'],
#  ['pe', 'ana'],
#  ['pes', 'ana'],
#  ['pe', 'as'],
#  ['pe', 'ass'],
#  ['pi', 'ass'],
#  ['re', 'ail'],
#  ['res', 'ail'],
#  ['roe', 'ais'],
#  ['ret', 'ars'],
#  ['rete', 'arse'],
#  ['rete', 'arses'],
#  ['re', 'as'],
#  ['re', 'ass'],
#  ['so', 'act'],
#  ['sos', 'act'],
#  ['sit', 'ass'],
#  ['ta', 'am'],
#  ['ten', 'awe'],
#  ['ut', 'an'],
#  ['ut', 'any'],
#  ['uit', 'ars'],
#  ['vis', 'aal'],
#  ['vas', 'ain'],
#  ['we', 'ae'],
#  ['wos', 'amu'],
#  ['we', 'and'],
#  ['ae', 'bad'],
#  ['as', 'ba'],
#  ['ar', 'bin'],
#  ['ars', 'bin'],
#  ['at', 'bi'],
#  ['at', 'bis'],
#  ['ads', 'blet'],
#  ['aloe', 'blond'],
#  ['ami', 'brad'],
#  ['amis', 'brad'],
#  ['ados', 'burn'],
#  ['ad', 'bus'],
#  ['as', 'by'],
#  ['ekes', 'bals'],
#  ['em', 'ba'],
#  ['emes', 'bals'],
#  ['em', 'bas'],
#  ['em', 'bay'],
#  ['en', 'ba'],
#  ['en', 'bas'],
#  ['er', 'ba'],
#  ['er', 'bad'],
#  ['ers', 'bad'],
#  ['er', 'bas'],
#  ['es', 'bat'],
#  ['ess', 'bat'],
#  ['et', 'ba'],
#  ['et', 'bas'],
#  ['ef', 'be'],
#  ['ef', 'bey'],
#  ['en', 'be'],
#  ['er', 'be'],
#  ['er', 'bey'],
#  ['es', 'be'],
#  ['et', 'be'],
#  ['en', 'big'],
#  ['ens', 'big'],
#  ['es', 'by'],
#  ['ho', 'bot'],
#  ['is', 'ba'],
#  ['in', 'bot'],
#  ['ins', 'bot'],
#  ['is', 'bo'],
#  ['it', 'boa'],
#  ['its', 'boa'],
#  ['li', 'ban'],
#  ['lis', 'ban'],
#  ['la', 'bet'],
#  ['las', 'bet'],
#  ['la', 'bot'],
#  ['las', 'bot'],
#  ['lo', 'bod'],
#  ['lord', 'bode'],
#  ['lo', 'bop'],
#  ['lees', 'buns'],
#  ['let', 'bus'],
#  ['ley', 'bus'],
#  ['or', 'ba'],
#  ['or', 'bad'],
#  ['ors', 'bad'],
#  ['or', 'bas'],
#  ['or', 'bat'],
#  ['ors', 'bat'],
#  ['os', 'ba'],
#  ['os', 'bat'],
#  ['ods', 'blet'],
#  ['ode', 'bold'],
#  ['oe', 'bod'],
#  ['oho', 'boo'],
#  ['oho', 'boos'],
#  ['oke', 'bolt'],
#  ['okes', 'bolt'],
#  ['om', 'bo'],
#  ['om', 'bos'],
#  ['om', 'boy'],
#  ['on', 'bo'],
#  ['on', 'bos'],
#  ['or', 'bo'],
#  ['or', 'bos'],
#  ['os', 'bo'],
#  ['os', 'bot'],
#  ['on', 'bud'],
#  ['ons', 'bud'],
#  ['or', 'bug'],
#  ['ors', 'bug'],
#  ['or', 'bun'],
#  ['ore', 'bun'],
#  ['ore', 'buns'],
#  ['ors', 'bun'],
#  ['ore', 'bus'],
#  ['ore', 'buss'],
#  ['os', 'buy'],
#  ['os', 'by'],
#  ['re', 'ba'],
#  ['re', 'bas'],
#  ['ras', 'bed'],
#  ['rah', 'bet'],
#  ['rah', 'bets'],
#  ['re', 'be'],
#  ['re', 'bed'],
#  ['res', 'bed'],
#  ['re', 'bi'],
#  ['re', 'bis'],
#  ['ras', 'bod'],
#  ['urn', 'brig'],
#  ['us', 'bra'],
#  ['use', 'bra'],
#  ['use', 'bred'],
#  ['uses', 'bred'],
#  ['us', 'by'],
#  ['yod', 'bra'],
#  ['yod', 'bras'],
#  ['aloe', 'clip'],
#  ['aloe', 'clips'],
#  ['ane', 'cris'],
#  ['an', 'cry'],
#  ['are', 'cris'],
#  ['ar', 'cry'],
#  ['as', 'cue'],
#  ['ass', 'cue'],
#  ['ell', 'clue'],
#  ['ells', 'clue'],
#  ['er', 'col'],
#  ['ers', 'col'],
#  ['hi', 'can'],
#  ['hie', 'can'],
#  ['hie', 'cans'],
#  ['his', 'can'],
#  ['hi', 'car'],
#  ['hie', 'card'],
#  ['his', 'car'],
#  ['hut', 'can'],
#  ['hut', 'cans'],
#  ['heir', 'cere'],
#  ['hie', 'cord'],
#  ['hoe', 'cos'],
#  ['hoe', 'coss'],
#  ['hoe', 'cosy'],
#  ['hoy', 'cos'],
#  ['huh', 'cog'],
#  ['huh', 'cogs'],
#  ['hue', 'cos'],
#  ['hue', 'coss'],
#  ['huh', 'cos'],
#  ['in', 'cos'],
#  ['li', 'cam'],
#  ['lis', 'cam'],
#  ['lo', 'cot'],
#  ['op', 'cat'],
#  ['ops', 'cat'],
#  ['os', 'cat'],
#  ['old', 'clue'],
#  ['olds', 'clue'],
#  ['oe', 'cod'],
#  ['oe', 'coy'],
#  ['oes', 'coy'],
#  ['of', 'cos'],
#  ['okes', 'cols'],
#  ['oles', 'cons'],
#  ['om', 'cob'],
#  ['oms', 'cob'],
#  ['on', 'cos'],
#  ['op', 'cos'],
#  ['op', 'cot'],
#  ['ops', 'cot'],
#  ['obe', 'cris'],
#  ['od', 'cry'],
#  ['on', 'cry'],
#  ['ore', 'cris'],
#  ['od', 'cue'],
#  ['ole', 'cue'],
#  ['ole', 'cues'],
#  ['on', 'cut'],
#  ['ones', 'cuts'],
#  ['ons', 'cut'],
#  ['op', 'cue'],
#  ['ops', 'cue'],
#  ['ope', 'cult'],
#  ['opes', 'cult'],
#  ['ore', 'cuss'],
#  ['or', 'cut'],
#  ['ors', 'cut'],
#  ['ree', 'cess'],
#  ['rue', 'cop'],
#  ['rue', 'cops'],
#  ['rue', 'cos'],
#  ['re', 'cut'],
#  ['res', 'cut'],
#  ['anis', 'dite'],
#  ['any', 'dit'],
#  ['ass', 'die'],
#  ['ate', 'dui'],
#  ['ef', 'da'],
#  ['el', 'da'],
#  ['en', 'da'],
#  ['er', 'da'],
#  ['ere', 'dais'],
#  ['er', 'day'],
#  ['es', 'dah'],
#  ['et', 'dah'],
#  ['em', 'de'],
#  ['em', 'des'],
#  ['er', 'de'],
#  ['er', 'des'],
#  ['es', 'de'],
#  ['es', 'dim'],
#  ['ess', 'dim'],
#  ['es', 'dit'],
#  ['ess', 'dit'],
#  ['er', 'dry'],
#  ['hoy', 'dol'],
#  ['ire', 'dais'],
#  ['id', 'de'],
#  ['in', 'dee'],
#  ['ins', 'dee'],
#  ['is', 'de'],
#  ['it', 'de'],
#  ['it', 'des'],
#  ['id', 'doe'],
#  ['ids', 'doe'],
#  ['it', 'dry'],
#  ['or', 'de'],
#  ['or', 'des'],
#  ['os', 'de'],
#  ['old', 'die'],
#  ['on', 'dig'],
#  ['ons', 'dig'],
#  ['ode', 'dol'],
#  ['ode', 'dols'],
#  ['ole', 'doe'],
#  ['ole', 'does'],
#  ['om', 'do'],
#  ['om', 'dos'],
#  ['or', 'do'],
#  ['ores', 'dols'],
#  ['or', 'dos'],
#  ['om', 'dry'],
#  ['ors', 'duet'],
#  ['ores', 'duns'],
#  ['os', 'due'],
#  ['rya', 'damn'],
#  ['rye', 'damn'],
#  ['re', 'de'],
#  ['re', 'des'],
#  ['re', 'did'],
#  ['uns', 'dees'],
#  ['us', 'de'],
#  ['ut', 'de'],
#  ['ut', 'des'],
#  ['us', 'do'],
#  ['alp', 'era'],
#  ['alp', 'eras'],
#  ['an', 'er'],
#  ['and', 'ere'],
#  ['an', 'ers'],
#  ['as', 'er'],
#  ['ae', 'es'],
#  ['ae', 'ess'],
#  ['at', 'es'],
#  ['at', 'ess'],
#  ['ay', 'es'],
#  ['ah', 'et'],
#  ['as', 'et'],
#  ['es', 'el'],
#  ['fee', 'eft'],
#  ['li', 'eh'],
#  ['li', 'eon'],
#  ['lis', 'eon'],
#  ['nae', 'egg'],
#  ['nae', 'eggs'],
#  ['nit', 'els'],
#  ['nae', 'erg'],
#  ['nae', 'ergs'],
#  ['not', 'eros'],
#  ['os', 'en'],
#  ['pa', 'eh'],
#  ['re', 'en'],
#  ['re', 'ens'],
#  ['rad', 'ern'],
#  ['rad', 'erns'],
#  ['rat', 'ern'],
#  ['rat', 'erns'],
#  ['rig', 'ern'],
#  ['re', 'ess'],
#  ['ta', 'en'],
#  ['ta', 'ens'],
#  ['ye', 'en'],
#  ['ya', 'er'],
#  ['ya', 'ers'],
#  ['ye', 'er'],
#  ['ye', 'ers'],
#  ['ar', 'fey'],
#  ['ale', 'fil'],
#  ['ale', 'fils'],
#  ['an', 'fit'],
#  ['ares', 'fins'],
#  ['el', 'fa'],
#  ['er', 'fa'],
#  ['er', 'fas'],
#  ['es', 'fat'],
#  ['ess', 'fat'],
#  ['et', 'fa'],
#  ['et', 'fas'],
#  ['els', 'fees'],
#  ['en', 'fit'],
#  ['ens', 'fit'],
#  ['es', 'fit'],
#  ['ess', 'fit'],
#  ['el', 'fly'],
#  ['el', 'fry'],
#  ['en', 'fry'],
#  ['er', 'fry'],
#  ['ice', 'far'],
#  ['it', 'fa'],
#  ['it', 'fas'],
#  ['in', 'fed'],
#  ['ins', 'fed'],
#  ['li', 'far'],
#  ['lis', 'far'],
#  ['leet', 'fets'],
#  ['lens', 'fetes'],
#  ['lo', 'for'],
#  ['let', 'fun'],
#  ['li', 'fud'],
#  ['lis', 'fud'],
#  ['lo', 'fur'],
#  ['om', 'fa'],
#  ['om', 'fas'],
#  ['om', 'fay'],
#  ['oh', 'fen'],
#  ['ohs', 'fen'],
#  ['obe', 'fil'],
#  ['obe', 'fils'],
#  ['old', 'fie'],
#  ['os', 'fit'],
#  ['old', 'foe'],
#  ['obe', 'fry'],
#  ['od', 'fro'],
#  ['own', 'fret'],
#  ['oles', 'funs'],
#  ['on', 'fud'],
#  ['ons', 'fud'],
#  ['re', 'fa'],
#  ['re', 'fed'],
#  ['rees', 'fens'],
#  ['re', 'fer'],
#  ['res', 'fer'],
#  ['ree', 'fez'],
#  ['ras', 'fir'],
#  ['ray', 'fir'],
#  ['re', 'fid'],
#  ['red', 'fin'],
#  ['redd', 'fine'],
#  ['red', 'fins'],
#  ['re', 'fir'],
#  ['res', 'fir'],
#  ['ree', 'fiz'],
#  ['urn', 'frig'],
#  ['urns', 'frig'],
#  ['and', 'gie'],
#  ['age', 'gnu'],
#  ['age', 'gnus'],
#  ['ad', 'guy'],
#  ['an', 'gut'],
#  ['er', 'gas'],
#  ['es', 'gee'],
#  ['es', 'get'],
#  ['ess', 'get'],
#  ['in', 'gat'],
#  ['ins', 'gat'],
#  ['inn', 'grig'],
#  ['li', 'gar'],
#  ['lie', 'gar'],
#  ['lie', 'gars'],
#  ['lis', 'gar'],
#  ['la', 'gem'],
#  ['las', 'gem'],
#  ['lay', 'gem'],
#  ['ley', 'get'],
#  ['la', 'got'],
#  ['las', 'got'],
#  ['odd', 'gae'],
#  ['od', 'gas'],
#  ['old', 'gae'],
#  ['oles', 'gals'],
#  ['on', 'gig'],
#  ['ons', 'gig'],
#  ['od', 'go'],
#  ['od', 'goy'],
#  ['oe', 'goy'],
#  ['of', 'go'],
#  ['of', 'goy'],
#  ['on', 'go'],
#  ['on', 'goy'],
#  ['op', 'go'],
#  ['os', 'go'],
#  ['os', 'goy'],
#  ['ras', 'gal'],
#  ['ras', 'get'],
#  ['re', 'ged'],
#  ['res', 'ged'],
#  ['reis', 'genet'],
#  ['re', 'get'],
#  ['res', 'get'],
#  ['ryes', 'gens'],
#  ['ras', 'got'],
#  ['rudd', 'gone'],
#  ['re', 'gul'],
#  ['res', 'gul'],
#  ['un', 'gas'],
#  ['us', 'get'],
#  ['us', 'gie'],
#  ['ar', 'ha'],
#  ['ar', 'has'],
#  ['ad', 'he'],
#  ['am', 'he'],
#  ['am', 'hes'],
#  ['an', 'he'],
#  ['as', 'he'],
#  ['at', 'he'],
#  ['at', 'hes'],
#  ['ar', 'hi'],
#  ['ar', 'his'],
#  ['an', 'hut'],
#  ['el', 'ha'],
#  ['eld', 'hae'],
#  ['el', 'has'],
#  ['er', 'ha'],
#  ['er', 'had'],
#  ['err', 'hae'],
#  ['err', 'haes'],
#  ['er', 'has'],
#  ['ere', 'has'],
#  ['er', 'hat'],
#  ['ers', 'hat'],
#  ['et', 'ha'],
#  ['et', 'hah'],
#  ['et', 'has'],
#  ['eve', 'hair'],
#  ['el', 'he'],
#  ['el', 'hes'],
#  ['el', 'hi'],
#  ['eld', 'hie'],
#  ['el', 'his'],
#  ['er', 'hi'],
#  ['ers', 'hies'],
#  ['er', 'his'],
#  ['es', 'hit'],
#  ['ess', 'hit'],
#  ['id', 'he'],
#  ['is', 'he'],
#  ['or', 'ha'],
#  ['or', 'had'],
#  ['ors', 'had'],
#  ['ore', 'hair'],
#  ['or', 'has'],
#  ['ore', 'has'],
#  ['or', 'hay'],
#  ['ox', 'ha'],
#  ['od', 'he'],
#  ['or', 'he'],
#  ['or', 'hes'],
#  ['os', 'he'],
#  ['os', 'hie'],
#  ['os', 'hit'],
#  ['od', 'ho'],
#  ['odd', 'hoe'],
#  ['oe', 'hoy'],
#  ['oes', 'hoy'],
#  ['of', 'ho'],
#  ['oke', 'holt'],
#  ['okes', 'holt'],
#  ['op', 'ho'],
#  ['os', 'hue'],
#  ['us', 'he'],
#  ['girn', 'into'],
#  ['net', 'ifs'],
#  ['no', 'if'],
#  ['no', 'ifs'],
#  ['no', 'it'],
#  ['os', 'in'],
#  ['sees', 'ills'],
#  ['an', 'jut'],
#  ['any', 'jut'],
#  ['err', 'jee'],
#  ['err', 'jees'],
#  ['os', 'jut'],
#  ['as', 'ka'],
#  ['an', 'kos'],
#  ['es', 'ka'],
#  ['ens', 'keet'],
#  ['era', 'kris'],
#  ['ere', 'kris'],
#  ['li', 'keg'],
#  ['on', 'ka'],
#  ['on', 'kas'],
#  ['os', 'ka'],
#  ['ad', 'li'],
#  ['an', 'li'],
#  ['ar', 'li'],
#  ['ar', 'lid'],
#  ['ars', 'lid'],
#  ['ar', 'lis'],
#  ['ef', 'la'],
#  ['ef', 'las'],
#  ['ef', 'lay'],
#  ['eke', 'lair'],
#  ['el', 'la'],
#  ['en', 'la'],
#  ['en', 'las'],
#  ['en', 'lat'],
#  ['er', 'la'],
#  ['ere', 'lair'],
#  ['ere', 'land'],
#  ['er', 'las'],
#  ['er', 'lay'],
#  ['es', 'la'],
#  ['es', 'lat'],
#  ['ess', 'lat'],
#  ['eve', 'lair'],
#  ['er', 'ley'],
#  ['es', 'li'],
#  ['in', 'lag'],
#  ['ins', 'lag'],
#  ['ifs', 'leet'],
#  ['ire', 'lens'],
#  ['in', 'lo'],
#  ['od', 'la'],
#  ['od', 'las'],
#  ['of', 'la'],
#  ['of', 'las'],
#  ['om', 'la'],
#  ['om', 'las'],
#  ['om', 'lay'],
#  ['on', 'la'],
#  ['on', 'las'],
#  ['ose', 'less'],
#  ['on', 'li'],
#  ['on', 'lis'],
#  ['of', 'lo'],
#  ['om', 'lo'],
#  ['on', 'lo'],
#  ['op', 'lo'],
#  ['os', 'lo'],
#  ['one', 'lug'],
#  ['one', 'lugs'],
#  ['ar', 'ma'],
#  ['ar', 'mas'],
#  ['as', 'me'],
#  ['ad', 'mi'],
#  ['ad', 'mis'],
#  ['age', 'mir'],
#  ['ales', 'mils'],
#  ['am', 'mi'],
#  ['am', 'mis'],
#  ['an', 'mi'],
#  ['any', 'mil'],
#  ['an', 'mis'],
#  ['ar', 'mi'],
#  ['ar', 'mis'],
#  ['an', 'mu'],
#  ['an', 'mud'],
#  ['any', 'mud'],
#  ['at', 'mu'],
#  ['at', 'mus'],
#  ['aa', 'my'],
#  ['as', 'my'],
#  ['el', 'ma'],
#  ['el', 'mas'],
#  ['el', 'may'],
#  ['en', 'ma'],
#  ['en', 'mas'],
#  ['en', 'mat'],
#  ['en', 'may'],
#  ['et', 'ma'],
#  ['et', 'mas'],
#  ['et', 'may'],
#  ['et', 'me'],
#  ['eke', 'mil'],
#  ['in', 'me'],
#  ['on', 'ma'],
#  ['on', 'mas'],
#  ['os', 'ma'],
#  ['oe', 'mod'],
#  ['ones', 'mols'],
#  ['one', 'molt'],
#  ['ones', 'molt'],
#  ['one', 'most'],
#  ['ones', 'most'],
#  ['oe', 'mu'],
#  ['oe', 'mus'],
#  ['oil', 'mule'],
#  ['on', 'mud'],
#  ['ons', 'mud'],
#  ['on', 'mut'],
#  ['ons', 'mut'],
#  ['or', 'mun'],
#  ['ors', 'mun'],
#  ['ose', 'mus'],
#  ['ose', 'muss'],
#  ['ai', 'no'],
#  ['as', 'no'],
#  ['er', 'na'],
#  ['err', 'nae'],
#  ['et', 'na'],
#  ['es', 'nit'],
#  ['en', 'no'],
#  ['en', 'nos'],
#  ['em', 'nu'],
#  ['em', 'nus'],
#  ['eta', 'nurl'],
#  ['etas', 'nurl'],
#  ['on', 'no'],
#  ['on', 'nos'],
#  ['on', 'nu'],
#  ['on', 'nus'],
#  ['os', 'nu'],
#  ['as', 'of'],
#  ['as', 'or'],
#  ['at', 'os'],
#  ['by', 'oe'],
#  ['by', 'oes'],
#  ['cee', 'ora'],
#  ['da', 'oe'],
#  ['eve', 'our'],
#  ['eve', 'ours'],
#  ['gait', 'ohms'],
#  ['gas', 'ohm'],
#  ['ka', 'or'],
#  ['ka', 'ors'],
#  ['let', 'ods'],
#  ['li', 'ode'],
#  ['lis', 'ode'],
#  ['la', 'oe'],
#  ['lo', 'oe'],
#  ['lo', 'oes'],
#  ['os', 'oh'],
#  ['os', 'op'],
#  ['re', 'oil'],
#  ['res', 'oil'],
#  ['roe', 'oil'],
#  ['roe', 'oils'],
#  ['us', 'od'],
#  ['us', 'or'],
#  ['ut', 'os'],
#  ['we', 'os'],
#  ['aa', 'pen'],
#  ['aas', 'pen'],
#  ['ad', 'pi'],
#  ['an', 'pi'],
#  ['and', 'pie'],
#  ['an', 'pis'],
#  ['an', 'pit'],
#  ['any', 'pit'],
#  ['ar', 'pi'],
#  ['ar', 'pis'],
#  ['as', 'pia'],
#  ['ass', 'pia'],
#  ['as', 'pie'],
#  ['am', 'ply'],
#  ['as', 'ply'],
#  ['ad', 'pry'],
#  ['aits', 'pree'],
#  ['art', 'pro'],
#  ['art', 'pros'],
#  ['ar', 'pry'],
#  ['at', 'pry'],
#  ['ate', 'psis'],
#  ['ae', 'pye'],
#  ['eke', 'pair'],
#  ['ekes', 'pals'],
#  ['el', 'pa'],
#  ['el', 'pas'],
#  ['en', 'pa'],
#  ['en', 'pas'],
#  ['er', 'pa'],
#  ['er', 'pal'],
#  ['ers', 'pal'],
#  ['er', 'pas'],
#  ['er', 'pat'],
#  ['es', 'pa'],
#  ['et', 'pa'],
#  ['et', 'pas'],
#  ['et', 'pay'],
#  ['el', 'pe'],
#  ['eld', 'pee'],
#  ['el', 'pes'],
#  ['en', 'pe'],
#  ['end', 'pee'],
#  ['en', 'pes'],
#  ['er', 'pe'],
#  ['ers', 'pees'],
#  ['er', 'pes'],
#  ['es', 'pe'],
#  ['ewe', 'pee'],
#  ['ewe', 'pees'],
#  ['en', 'pi'],
#  ['end', 'pie'],
#  ['en', 'pis'],
#  ['es', 'pie'],
#  ['ess', 'pie'],
#  ['ern', 'pro'],
#  ['ern', 'pros'],
#  ['er', 'pry'],
#  ['in', 'pa'],
#  ['in', 'pas'],
#  ['is', 'pa'],
#  ['id', 'pe'],
#  ['is', 'pe'],
#  ['it', 'pea'],
#  ['its', 'pea'],
#  ['in', 'pig'],
#  ['lie', 'pac'],
#  ['lie', 'pacs'],
#  ['li', 'pad'],
#  ['lis', 'pad'],
#  ['li', 'pan'],
#  ['lins', 'panes'],
#  ['lis', 'pan'],
#  ['lit', 'pan'],
#  ['lit', 'pans'],
#  ['li', 'pat'],
#  ['lis', 'pat'],
#  ['lyes', 'pals'],
#  ['la', 'pe'],
#  ['la', 'ped'],
#  ['las', 'ped'],
#  ['la', 'pes'],
#  ['la', 'pet'],
#  ['las', 'pet'],
#  ['lid', 'pea'],
#  ['lid', 'peas'],
#  ['loam', 'pens'],
#  ['lac', 'piny'],
#  ['lat', 'pin'],
#  ['om', 'pe'],
#  ['om', 'pes'],
#  ['on', 'pit'],
#  ['one', 'pit'],
#  ['one', 'pits'],
#  ['ons', 'pit'],
#  ['os', 'pi'],
#  ['os', 'pie'],
#  ['ode', 'pol'],
#  ['ode', 'pols'],
#  ['ors', 'poet'],
#  ['or', 'poi'],
#  ['ors', 'poi'],
#  ['ores', 'pons'],
#  ['on', 'pro'],
#  ['ons', 'pro'],
#  ['of', 'pus'],
#  ['on', 'pud'],
#  ['ons', 'pud'],
#  ['or', 'pus'],
#  ['ras', 'pam'],
#  ['ram', 'per'],
#  ['re', 'pe'],
#  ['re', 'ped'],
#  ['re', 'pen'],
#  ['ree', 'pend'],
#  ['res', 'pen'],
#  ['re', 'pes'],
#  ['re', 'pis'],
#  ['ret', 'pis'],
#  ['ret', 'piss'],
#  ['slit', 'pams'],
#  ['use', 'pin'],
#  ['use', 'pins'],
#  ['up', 'ply'],
#  ['urn', 'prig'],
#  ['us', 'pry'],
#  ['use', 'psis'],
#  ['anus', 'riot'],
#  ['el', 'ram'],
#  ['els', 'ram'],
#  ['el', 'ras'],
#  ['em', 'ras'],
#  ['er', 'ram'],
#  ['ers', 'ram'],
#  ['er', 'ras'],
#  ['ef', 're'],
#  ['ef', 'res'],
#  ['el', 're'],
#  ['eld', 'ree'],
#  ['el', 'res'],
#  ['es', 're'],
#  ['es', 'ret'],
#  ['ess', 'ret'],
#  ['es', 'rue'],
#  ['ess', 'rue'],
#  ['ha', 're'],
#  ['ha', 'res'],
#  ['in', 'rat'],
#  ['od', 'ras'],
#  ['om', 'ras'],
#  ['on', 'ras'],
#  ['or', 'ras'],
#  ['os', 'rat'],
#  ['os', 're'],
#  ['os', 'roe'],
#  ['os', 'rot'],
#  ['oe', 'run'],
#  ['oes', 'run'],
#  ['one', 'rudd'],
#  ['opt', 'rue'],
#  ['os', 'rue'],
#  ['os', 'rut'],
#  ['us', 're'],
#  ['unbe', 'rial'],
#  ['un', 'rig'],
#  ['ad', 'si'],
#  ['ad', 'sis'],
#  ['an', 'si'],
#  ['an', 'sis'],
#  ['an', 'sit'],
#  ['ale', 'slid'],
#  ['at', 'sly'],
#  ['aha', 'sped'],
#  ['aine', 'specs'],
#  ['ait', 'stey'],
#  ['at', 'sue'],
#  ['ate', 'sued'],
#  ['cry', 'sae'],
#  ['cold', 'shoe'],
#  ['cos', 'sin'],
#  ['cos', 'sop'],
#  ['cos', 'sot'],
#  ['cue', 'sord'],
#  ['cue', 'sos'],
#  ['cris', 'sure'],
#  ['eld', 'sae'],
#  ['emes', 'sals'],
#  ['em', 'say'],
#  ['err', 'sae'],
#  ['eld', 'see'],
#  ['ers', 'sees'],
#  ['eger', 'sinus'],
#  ['es', 'si'],
#  ['es', 'sim'],
#  ['ess', 'sim'],
#  ['et', 'spa'],
#  ['ere', 'sris'],
#  ['huh', 'sag'],
#  ['huh', 'sags'],
#  ['ha', 'sel'],
#  ['has', 'sel'],
#  ['ha', 'ser'],
#  ['has', 'ser'],
#  ['hah', 'set'],
#  ['hah', 'sets'],
#  ['he', 'sen'],
#  ['hes', 'sen'],
#  ['hey', 'sen'],
#  ['he', 'ser'],
#  ['hes', 'ser'],
#  ['he', 'set'],
#  ['hes', 'set'],
#  ['ho', 'sel'],
#  ['huh', 'sec'],
#  ['huh', 'secs'],
#  ['he', 'sir'],
#  ['hes', 'sir'],
#  ['he', 'sis'],
#  ['het', 'sis'],
#  ['ha', 'sol'],
#  ['hae', 'sold'],
#  ['haet', 'sols'],
#  ['hair', 'sole'],
#  ['has', 'sol'],
#  ['hay', 'sol'],
#  ['ha', 'sot'],
#  ['has', 'sot'],
#  ['he', 'so'],
#  ['he', 'sod'],
#  ['he', 'sos'],
#  ['ho', 'so'],
#  ['ho', 'sol'],
#  ['hoe', 'sold'],
#  ['ho', 'son'],
#  ['ho', 'sos'],
#  ['ho', 'sot'],
#  ['it', 'sly'],
#  ['ka', 'sen'],
#  ['kae', 'sen'],
#  ['kas', 'sen'],
#  ['kris', 'sere'],
#  ['ka', 'sol'],
#  ['kae', 'sold'],
#  ['kas', 'sol'],
#  ['ley', 'set'],
#  ['let', 'sis'],
#  ['li', 'sod'],
#  ['lis', 'sod'],
#  ['lo', 'sop'],
#  ['ma', 'ser'],
#  ['mair', 'sere'],
#  ['mas', 'ser'],
#  ['may', 'ser'],
#  ['nth', 'sac'],
#  ['nth', 'sic'],
#  ['no', 'sod'],
#  ['nos', 'sod'],
#  ['no', 'sol'],
#  ['nos', 'sol'],
#  ...]

# %%
s1=[]
s2=[]
for i in range(len('hello')):
    
    if i%2!=0:
        s1.append('hello'[i])
    elif i%2==0:
        s2.append('hello'[i])
b=''.join(s1)
print(b)
# Out:
# el

# %%
def husuo():
#     a=[]
    t=read_words()
    for s in t:
        s1=[]
        s2=[]
        for i in range(len(s)):
            
            if i%2!=0:
                s1.append(s[i])
            elif i%2==0:
                s2.append(s[i])
        word1=''.join(s1)
        word2=''.join(s2)
        if find_lt(t,word1) and find_lt(t,word2):
            print(word1+'   '+word2 +'     '+s)
#     return a
husuo()
# Out:
# as   ah     aahs
# be   aby     abbey
# be   aid     abied
# be   ais     abies
# bi   ar     abri
# bi   ars     abris
# be   ay     abye
# be   ays     abyes
# cos   ars     across
# de   add     added
# do   ais     adios
# don   anus     adnouns
# dit   arf     adrift
# doty   aril     adroitly
# fed   ail     afield
# fet   are     afreet
# fet   ares     afreets
# go   ai     agio
# go   ais     agios
# gem   ala     agleam
# gal   ani     agnail
# gal   anis     agnails
# gae   ant     agnate
# gae   ants     agnates
# gae   arf     agrafe
# gain   arras     agrarians
# ged   are     agreed
# is   ad     aids
# is   am     aims
# is   an     ains
# in   ar     airn
# in   ars     airns
# is   ar     airs
# it   ar     airt
# it   ars     airts
# is   at     aits
# la   age     algae
# la   ais     alias
# lee   aine     alienee
# lees   aine     alienees
# lee   all     allele
# lee   alls     alleles
# lid   ale     allied
# lis   ale     allies
# lo   alt     allot
# la   am     alma
# lie   ask     alsike
# lie   asks     alsikes
# lo   as     also
# lo   at     alto
# ma   ai     amia
# ma   ais     amias
# me   ai     amie
# me   ais     amies
# mi   ana     amnia
# met   area     amreeta
# no   ain     anion
# nos   ain     anions
# na   an     anna
# nae   ants     annates
# no   any     annoy
# nos   any     annoys
# na   as     ansa
# na   at     anta
# na   ate     antae
# pa   ain     apian
# pay   air     apiary
# pie   alt     aplite
# pie   alts     aplites
# pe   ana     apnea
# pes   ana     apneas
# pe   as     apse
# pe   ass     apses
# pi   ass     apsis
# re   ail     ariel
# res   ail     ariels
# roe   ais     ariose
# ret   ars     arrest
# rete   arse     arrestee
# rete   arses     arrestees
# re   as     arse
# re   ass     arses
# so   act     ascot
# sos   act     ascots
# sit   ass     assist
# ta   am     atma
# ten   awe     atween
# ut   an     aunt
# ut   any     aunty
# uit   ars     aurist
# vis   aal     avails
# vas   ain     avians
# we   ae     awee
# wos   amu     awmous
# we   and     awned
# ae   bad     baaed
# as   ba     baas
# ar   bin     bairn
# ars   bin     bairns
# at   bi     bait
# at   bis     baits
# ads   blet     baldest
# aloe   blond     ballooned
# ami   brad     barmaid
# amis   brad     barmaids
# ados   burn     baudrons
# ad   bus     bauds
# as   by     bays
# ekes   bals     beakless
# em   ba     beam
# emes   bals     beamless
# em   bas     beams
# em   bay     beamy
# en   ba     bean
# en   bas     beans
# er   ba     bear
# er   bad     beard
# ers   bad     beards
# er   bas     bears
# es   bat     beast
# ess   bat     beasts
# et   ba     beat
# et   bas     beats
# ef   be     beef
# ef   bey     beefy
# en   be     been
# er   be     beer
# er   bey     beery
# es   be     bees
# et   be     beet
# en   big     being
# ens   big     beings
# es   by     beys
# ho   bot     bhoot
# is   ba     bias
# in   bot     biont
# ins   bot     bionts
# is   bo     bios
# it   boa     biota
# its   boa     biotas
# li   ban     blain
# lis   ban     blains
# la   bet     bleat
# las   bet     bleats
# la   bot     bloat
# las   bot     bloats
# lo   bod     blood
# lord   bode     bloodred
# lo   bop     bloop
# lees   buns     blueness
# let   bus     bluest
# ley   bus     bluesy
# or   ba     boar
# or   bad     board
# ors   bad     boards
# or   bas     boars
# or   bat     boart
# ors   bat     boarts
# os   ba     boas
# os   bat     boast
# ods   blet     boldest
# ode   bold     boodled
# oe   bod     booed
# oho   boo     boohoo
# oho   boos     boohoos
# oke   bolt     booklet
# okes   bolt     booklets
# om   bo     boom
# om   bos     booms
# om   boy     boomy
# on   bo     boon
# on   bos     boons
# or   bo     boor
# or   bos     boors
# os   bo     boos
# os   bot     boost
# on   bud     bound
# ons   bud     bounds
# or   bug     bourg
# ors   bug     bourgs
# or   bun     bourn
# ore   bun     bourne
# ore   buns     bournes
# ors   bun     bourns
# ore   bus     bourse
# ore   buss     bourses
# os   buy     bousy
# os   by     boys
# re   ba     brae
# re   bas     braes
# ras   bed     breads
# rah   bet     breath
# rah   bets     breaths
# re   be     bree
# re   bed     breed
# res   bed     breeds
# re   bi     brie
# re   bis     bries
# ras   bod     broads
# urn   brig     burring
# us   bra     bursa
# use   bra     bursae
# use   bred     burseed
# uses   bred     burseeds
# us   by     buys
# yod   bra     byroad
# yod   bras     byroads
# aloe   clip     calliope
# aloe   clips     calliopes
# ane   cris     carnies
# an   cry     carny
# are   cris     carries
# ar   cry     carry
# as   cue     cause
# ass   cue     causes
# ell   clue     cellule
# ells   clue     cellules
# er   col     ceorl
# ers   col     ceorls
# hi   can     chain
# hie   can     chaine
# hie   cans     chaines
# his   can     chains
# hi   car     chair
# hie   card     chaired
# his   car     chairs
# hut   can     chaunt
# hut   cans     chaunts
# heir   cere     cheerier
# hie   cord     choired
# hoe   cos     choose
# hoe   coss     chooses
# hoe   cosy     choosey
# hoy   cos     choosy
# huh   cog     chough
# huh   cogs     choughs
# hue   cos     chouse
# hue   coss     chouses
# huh   cos     choush
# in   cos     cions
# li   cam     claim
# lis   cam     claims
# lo   cot     cloot
# op   cat     coapt
# ops   cat     coapts
# os   cat     coast
# old   clue     collude
# olds   clue     colludes
# oe   cod     cooed
# oe   coy     cooey
# oes   coy     cooeys
# of   cos     coofs
# okes   cols     cookless
# oles   cons     coolness
# om   cob     coomb
# oms   cob     coombs
# on   cos     coons
# op   cos     coops
# op   cot     coopt
# ops   cot     coopts
# obe   cris     corbies
# od   cry     cordy
# on   cry     corny
# ore   cris     corries
# od   cue     coude
# ole   cue     coulee
# ole   cues     coulees
# on   cut     count
# ones   cuts     countess
# ons   cut     counts
# op   cue     coupe
# ops   cue     coupes
# ope   cult     couplet
# opes   cult     couplets
# ore   cuss     courses
# or   cut     court
# ors   cut     courts
# ree   cess     creeses
# rue   cop     croupe
# rue   cops     croupes
# rue   cos     crouse
# re   cut     cruet
# res   cut     cruets
# anis   dite     dainties
# any   dit     dainty
# ass   die     daises
# ate   dui     dautie
# ef   da     deaf
# el   da     deal
# en   da     dean
# er   da     dear
# ere   dais     dearies
# er   day     deary
# es   dah     deash
# et   dah     death
# em   de     deem
# em   des     deems
# er   de     deer
# er   des     deers
# es   de     dees
# es   dim     deism
# ess   dim     deisms
# es   dit     deist
# ess   dit     deists
# er   dry     derry
# hoy   dol     dhooly
# ire   dais     diaries
# id   de     died
# in   dee     diene
# ins   dee     dienes
# is   de     dies
# it   de     diet
# it   des     diets
# id   doe     diode
# ids   doe     diodes
# it   dry     dirty
# or   de     doer
# or   des     doers
# os   de     does
# old   die     doiled
# on   dig     doing
# ons   dig     doings
# ode   dol     doodle
# ode   dols     doodles
# ole   doe     doolee
# ole   does     doolees
# om   do     doom
# om   dos     dooms
# or   do     door
# ores   dols     doorless
# or   dos     doors
# om   dry     dormy
# ors   duet     dourest
# ores   duns     dourness
# os   due     douse
# rya   damn     drayman
# rye   damn     draymen
# re   de     dree
# re   des     drees
# re   did     dried
# uns   dees     dueness
# us   de     dues
# ut   de     duet
# ut   des     duets
# us   do     duos
# alp   era     earlap
# alp   eras     earlaps
# an   er     earn
# and   ere     earned
# an   ers     earns
# as   er     ears
# ae   es     ease
# ae   ess     eases
# at   es     east
# at   ess     easts
# ay   es     easy
# ah   et     eath
# as   et     eats
# es   el     eels
# fee   eft     effete
# li   eh     elhi
# li   eon     eloin
# lis   eon     eloins
# nae   egg     engage
# nae   eggs     engages
# nit   els     enlist
# nae   erg     enrage
# nae   ergs     enrages
# not   eros     enroots
# os   en     eons
# pa   eh     epha
# re   en     erne
# re   ens     ernes
# rad   ern     errand
# rad   erns     errands
# rat   ern     errant
# rat   erns     errants
# rig   ern     erring
# re   ess     erses
# ta   en     etna
# ta   ens     etnas
# ye   en     eyne
# ya   er     eyra
# ya   ers     eyras
# ye   er     eyre
# ye   ers     eyres
# ar   fey     faery
# ale   fil     faille
# ale   fils     failles
# an   fit     faint
# ares   fins     fairness
# el   fa     feal
# er   fa     fear
# er   fas     fears
# es   fat     feast
# ess   fat     feasts
# et   fa     feat
# et   fas     feats
# els   fees     feeless
# en   fit     feint
# ens   fit     feints
# es   fit     feist
# ess   fit     feists
# el   fly     felly
# el   fry     ferly
# en   fry     ferny
# er   fry     ferry
# ice   far     fiacre
# it   fa     fiat
# it   fas     fiats
# in   fed     fiend
# ins   fed     fiends
# li   far     flair
# lis   far     flairs
# leet   fets     fleetest
# lens   fetes     fleetness
# lo   for     floor
# let   fun     fluent
# li   fud     fluid
# lis   fud     fluids
# lo   fur     fluor
# om   fa     foam
# om   fas     foams
# om   fay     foamy
# oh   fen     foehn
# ohs   fen     foehns
# obe   fil     foible
# obe   fils     foibles
# old   fie     foiled
# os   fit     foist
# old   foe     fooled
# obe   fry     forbye
# od   fro     fordo
# own   fret     forwent
# oles   funs     foulness
# on   fud     found
# ons   fud     founds
# re   fa     frae
# re   fed     freed
# rees   fens     freeness
# re   fer     freer
# res   fer     freers
# ree   fez     freeze
# ras   fir     friars
# ray   fir     friary
# re   fid     fried
# red   fin     friend
# redd   fine     friended
# red   fins     friends
# re   fir     frier
# res   fir     friers
# ree   fiz     frieze
# urn   frig     furring
# urns   frig     furrings
# and   gie     gained
# age   gnu     gangue
# age   gnus     gangues
# ad   guy     gaudy
# an   gut     gaunt
# er   gas     gears
# es   gee     geese
# es   get     geest
# ess   get     geests
# in   gat     giant
# ins   gat     giants
# inn   grig     girning
# li   gar     glair
# lie   gar     glaire
# lie   gars     glaires
# lis   gar     glairs
# la   gem     gleam
# las   gem     gleams
# lay   gem     gleamy
# ley   get     gleety
# la   got     gloat
# las   got     gloats
# odd   gae     goaded
# od   gas     goads
# old   gae     goaled
# oles   gals     goalless
# on   gig     going
# ons   gig     goings
# od   go     good
# od   goy     goody
# oe   goy     gooey
# of   go     goof
# of   goy     goofy
# on   go     goon
# on   goy     goony
# op   go     goop
# os   go     goos
# os   goy     goosy
# ras   gal     graals
# ras   get     greats
# re   ged     greed
# res   ged     greeds
# reis   genet     greeniest
# re   get     greet
# res   get     greets
# ryes   gens     greyness
# ras   got     groats
# rudd   gone     grounded
# re   gul     gruel
# res   gul     gruels
# un   gas     guans
# us   get     guest
# us   gie     guise
# ar   ha     haar
# ar   has     haars
# ad   he     haed
# am   he     haem
# am   hes     haems
# an   he     haen
# as   he     haes
# at   he     haet
# at   hes     haets
# ar   hi     hair
# ar   his     hairs
# an   hut     haunt
# el   ha     heal
# eld   hae     healed
# el   has     heals
# er   ha     hear
# er   had     heard
# err   hae     hearer
# err   haes     hearers
# er   has     hears
# ere   has     hearse
# er   hat     heart
# ers   hat     hearts
# et   ha     heat
# et   hah     heath
# et   has     heats
# eve   hair     heavier
# el   he     heel
# el   hes     heels
# el   hi     heil
# eld   hie     heiled
# el   his     heils
# er   hi     heir
# ers   hies     heiress
# er   his     heirs
# es   hit     heist
# ess   hit     heists
# id   he     hied
# is   he     hies
# or   ha     hoar
# or   had     hoard
# ors   had     hoards
# ore   hair     hoarier
# or   has     hoars
# ore   has     hoarse
# or   hay     hoary
# ox   ha     hoax
# od   he     hoed
# or   he     hoer
# or   hes     hoers
# os   he     hoes
# os   hie     hoise
# os   hit     hoist
# od   ho     hood
# odd   hoe     hooded
# oe   hoy     hooey
# oes   hoy     hooeys
# of   ho     hoof
# oke   holt     hooklet
# okes   holt     hooklets
# op   ho     hoop
# os   hue     house
# us   he     hues
# girn   into     ignitron
# net   ifs     infest
# no   if     info
# no   ifs     infos
# no   it     into
# os   in     ions
# sees   ills     isleless
# an   jut     jaunt
# any   jut     jaunty
# err   jee     jeerer
# err   jees     jeerers
# os   jut     joust
# as   ka     kaas
# an   kos     kaons
# es   ka     keas
# ens   keet     keenest
# era   kris     kerrias
# ere   kris     kerries
# li   keg     kleig
# on   ka     koan
# on   kas     koans
# os   ka     koas
# ad   li     laid
# an   li     lain
# ar   li     lair
# ar   lid     laird
# ars   lid     lairds
# ar   lis     lairs
# ef   la     leaf
# ef   las     leafs
# ef   lay     leafy
# eke   lair     leakier
# el   la     leal
# en   la     lean
# en   las     leans
# en   lat     leant
# er   la     lear
# ere   lair     learier
# ere   land     learned
# er   las     lears
# er   lay     leary
# es   la     leas
# es   lat     least
# ess   lat     leasts
# eve   lair     leavier
# er   ley     leery
# es   li     leis
# in   lag     liang
# ins   lag     liangs
# ifs   leet     liefest
# ire   lens     liernes
# in   lo     lion
# od   la     load
# od   las     loads
# of   la     loaf
# of   las     loafs
# om   la     loam
# om   las     loams
# om   lay     loamy
# on   la     loan
# on   las     loans
# ose   less     loesses
# on   li     loin
# on   lis     loins
# of   lo     loof
# om   lo     loom
# on   lo     loon
# op   lo     loop
# os   lo     loos
# one   lug     lounge
# one   lugs     lounges
# ar   ma     maar
# ar   mas     maars
# as   me     maes
# ad   mi     maid
# ad   mis     maids
# age   mir     maigre
# ales   mils     mailless
# am   mi     maim
# am   mis     maims
# an   mi     main
# any   mil     mainly
# an   mis     mains
# ar   mi     mair
# ar   mis     mairs
# an   mu     maun
# an   mud     maund
# any   mud     maundy
# at   mu     maut
# at   mus     mauts
# aa   my     maya
# as   my     mays
# el   ma     meal
# el   mas     meals
# el   may     mealy
# en   ma     mean
# en   mas     means
# en   mat     meant
# en   may     meany
# et   ma     meat
# et   mas     meats
# et   may     meaty
# et   me     meet
# eke   mil     meikle
# in   me     mien
# on   ma     moan
# on   mas     moans
# os   ma     moas
# oe   mod     mooed
# ones   mols     moonless
# one   molt     moonlet
# ones   molt     moonlets
# one   most     moonset
# ones   most     moonsets
# oe   mu     moue
# oe   mus     moues
# oil   mule     mouille
# on   mud     mound
# ons   mud     mounds
# on   mut     mount
# ons   mut     mounts
# or   mun     mourn
# ors   mun     mourns
# ose   mus     mousse
# ose   muss     mousses
# ai   no     naoi
# as   no     naos
# er   na     near
# err   nae     nearer
# et   na     neat
# es   nit     neist
# en   no     neon
# en   nos     neons
# em   nu     neum
# em   nus     neums
# eta   nurl     neutral
# etas   nurl     neutrals
# on   no     noon
# on   nos     noons
# on   nu     noun
# on   nus     nouns
# os   nu     nous
# as   of     oafs
# as   or     oars
# at   os     oast
# by   oe     obey
# by   oes     obeys
# cee   ora     ocreae
# da   oe     odea
# eve   our     oeuvre
# eve   ours     oeuvres
# gait   ohms     oghamist
# gas   ohm     oghams
# ka   or     okra
# ka   ors     okras
# let   ods     oldest
# li   ode     oldie
# lis   ode     oldies
# la   oe     olea
# lo   oe     oleo
# lo   oes     oleos
# os   oh     oohs
# os   op     oops
# re   oil     oriel
# res   oil     oriels
# roe   oil     oriole
# roe   oils     orioles
# us   od     ouds
# us   or     ours
# ut   os     oust
# we   os     owse
# aa   pen     paean
# aas   pen     paeans
# ad   pi     paid
# an   pi     pain
# and   pie     pained
# an   pis     pains
# an   pit     paint
# any   pit     painty
# ar   pi     pair
# ar   pis     pairs
# as   pia     paisa
# ass   pia     paisas
# as   pie     paise
# am   ply     palmy
# as   ply     palsy
# ad   pry     pardy
# aits   pree     parietes
# art   pro     parrot
# art   pros     parrots
# ar   pry     parry
# at   pry     party
# ate   psis     pasties
# ae   pye     payee
# eke   pair     peakier
# ekes   pals     peakless
# el   pa     peal
# el   pas     peals
# en   pa     pean
# en   pas     peans
# er   pa     pear
# er   pal     pearl
# ers   pal     pearls
# er   pas     pears
# er   pat     peart
# es   pa     peas
# et   pa     peat
# et   pas     peats
# et   pay     peaty
# el   pe     peel
# eld   pee     peeled
# el   pes     peels
# en   pe     peen
# end   pee     peened
# en   pes     peens
# er   pe     peer
# ers   pees     peeress
# er   pes     peers
# es   pe     pees
# ewe   pee     peewee
# ewe   pees     peewees
# en   pi     pein
# end   pie     peined
# en   pis     peins
# es   pie     peise
# ess   pie     peises
# ern   pro     perron
# ern   pros     perrons
# er   pry     perry
# in   pa     pian
# in   pas     pians
# is   pa     pias
# id   pe     pied
# is   pe     pies
# it   pea     pieta
# its   pea     pietas
# in   pig     piing
# lie   pac     plaice
# lie   pacs     plaices
# li   pad     plaid
# lis   pad     plaids
# li   pan     plain
# lins   panes     plainness
# lis   pan     plains
# lit   pan     plaint
# lit   pans     plaints
# li   pat     plait
# lis   pat     plaits
# lyes   pals     playless
# la   pe     plea
# la   ped     plead
# las   ped     pleads
# la   pes     pleas
# la   pet     pleat
# las   pet     pleats
# lid   pea     pleiad
# lid   peas     pleiads
# loam   pens     pleonasm
# lac   piny     pliancy
# lat   pin     pliant
# om   pe     poem
# om   pes     poems
# on   pit     point
# one   pit     pointe
# one   pits     pointes
# ons   pit     points
# os   pi     pois
# os   pie     poise
# ode   pol     poodle
# ode   pols     poodles
# ors   poet     poorest
# or   poi     poori
# ors   poi     pooris
# ores   pons     poorness
# on   pro     porno
# ons   pro     pornos
# of   pus     poufs
# on   pud     pound
# ons   pud     pounds
# or   pus     pours
# ras   pam     praams
# ram   per     prearm
# re   pe     pree
# re   ped     preed
# re   pen     preen
# ree   pend     preened
# res   pen     preens
# re   pes     prees
# re   pis     pries
# ret   pis     priest
# ret   piss     priests
# slit   pams     psalmist
# use   pin     puisne
# use   pins     puisnes
# up   ply     pulpy
# urn   prig     purring
# us   pry     pursy
# use   psis     pussies
# anus   riot     rainouts
# el   ram     realm
# els   ram     realms
# el   ras     reals
# em   ras     reams
# er   ram     rearm
# ers   ram     rearms
# er   ras     rears
# ef   re     reef
# ef   res     reefs
# el   re     reel
# eld   ree     reeled
# el   res     reels
# es   re     rees
# es   ret     reest
# ess   ret     reests
# es   rue     reuse
# ess   rue     reuses
# ha   re     rhea
# ha   res     rheas
# in   rat     riant
# od   ras     roads
# om   ras     roams
# on   ras     roans
# or   ras     roars
# os   rat     roast
# os   re     roes
# os   roe     roose
# os   rot     roost
# oe   run     rouen
# oes   run     rouens
# one   rudd     rounded
# opt   rue     roupet
# os   rue     rouse
# os   rut     roust
# us   re     rues
# unbe   rial     ruinable
# un   rig     ruing
# ad   si     said
# ad   sis     saids
# an   si     sain
# an   sis     sains
# an   sit     saint
# ale   slid     sallied
# at   sly     salty
# aha   sped     saphead
# aine   specs     sapiences
# ait   stey     satiety
# at   sue     saute
# ate   sued     sauteed
# cry   sae     scarey
# cold   shoe     schooled
# cos   sin     scions
# cos   sop     scoops
# cos   sot     scoots
# cue   sord     scoured
# cue   sos     scouse
# cris   sure     scurries
# eld   sae     sealed
# emes   sals     seamless
# em   say     seamy
# err   sae     searer
# eld   see     seeled
# ers   sees     seeress
# eger   sinus     seigneurs
# es   si     seis
# es   sim     seism
# ess   sim     seisms
# et   spa     septa
# ere   sris     serries
# huh   sag     shaugh
# huh   sags     shaughs
# ha   sel     sheal
# has   sel     sheals
# ha   ser     shear
# has   ser     shears
# hah   set     sheath
# hah   sets     sheaths
# he   sen     sheen
# hes   sen     sheens
# hey   sen     sheeny
# he   ser     sheer
# hes   ser     sheers
# he   set     sheet
# hes   set     sheets
# ho   sel     sheol
# huh   sec     sheuch
# huh   secs     sheuchs
# he   sir     shier
# hes   sir     shiers
# he   sis     shies
# het   sis     shiest
# ha   sol     shoal
# hae   sold     shoaled
# haet   sols     shoalest
# hair   sole     shoalier
# has   sol     shoals
# hay   sol     shoaly
# ha   sot     shoat
# has   sot     shoats
# he   so     shoe
# he   sod     shoed
# he   sos     shoes
# ho   so     shoo
# ho   sol     shool
# hoe   sold     shooled
# ho   son     shoon
# ho   sos     shoos
# ho   sot     shoot
# it   sly     silty
# ka   sen     skean
# kae   sen     skeane
# kas   sen     skeans
# kris   sere     skerries
# ka   sol     skoal
# kae   sold     skoaled
# kas   sol     skoals
# ley   set     sleety
# let   sis     sliest
# li   sod     sloid
# lis   sod     sloids
# lo   sop     sloop
# ma   ser     smear
# mair   sere     smearier
# mas   ser     smears
# may   ser     smeary
# nth   sac     snatch
# nth   sic     snitch
# no   sod     snood
# nos   sod     snoods
# no   sol     snool
# nos   sol     snools
# no   sop     snoop
# nos   sop     snoops
# no   sot     snoot
# nos   sot     snoots
# nu   sot     snout
# nus   sot     snouts
# opes   sals     soapless
# op   say     soapy
# oe   soy     sooey
# on   so     soon
# ohs   spit     sophist
# oh   spy     sophy
# op   spy     soppy
# odd   sri     sordid
# old   sue     souled
# one   sudd     sounded
# ors   suet     sourest
# ores   suns     sourness
# os   sue     souse
# pe   sad     spaed
# pi   sal     spail
# pis   sal     spails
# pi   sat     spait
# pis   sat     spaits
# pa   sen     spean
# pas   sen     speans
# pa   ser     spear
# pas   ser     spears
# pe   sel     speel
# pes   sel     speels
# pe   ser     speer
# pes   ser     speers
# pi   sel     speil
# pis   sel     speils
# pi   ser     speir
# pis   ser     speirs
# pee   sild     spieled
# pe   sir     spier
# pes   sir     spiers
# pe   sis     spies
# pa   sly     splay
# pas   sly     splays
# pi   sol     spoil
# pie   sold     spoiled
# pis   sol     spoils
# pit   sol     spoilt
# pois   sone     spoonies
# pry   sot     sporty
# pus   sot     spouts
# pan   sri     sprain
# pan   sris     sprains
# pig   sun     spuing
# prig   sunn     spurning
# pig   syn     spying
# ti   sad     staid
# ti   sag     staig
# tis   sag     staigs
# tie   sand     stained
# tils   sanes     stainless
# ta   sel     steal
# tas   sel     steals
# ti   sen     stein
# tis   sen     steins
# ta   so     stoa
# ta   sos     stoas
# ta   sot     stoat
# tas   sot     stoats
# to   sod     stood
# to   sol     stool
# toe   sold     stooled
# to   sop     stoop
# tui   sore     stourie
# tan   sri     strain
# tan   sris     strains
# tat   sri     strait
# tat   sris     straits
# un   sit     suint
# uns   sit     suints
# ut   si     suit
# ut   sis     suits
# wis   sal     swails
# wry   sat     swarty
# was   ser     swears
# was   set     sweats
# way   set     sweaty
# we   ser     sweer
# we   set     sweet
# weet   sets     sweetest
# wo   son     swoon
# wos   son     swoons
# wo   sop     swoop
# wos   sop     swoops
# wud   son     swound
# wud   sons     swounds
# ale   til     taille
# ale   tils     tailles
# ales   tils     tailless
# an   ti     tain
# an   tis     tains
# an   tit     taint
# as   to     taos
# ad   try     tardy
# ar   try     tarry
# an   tut     taunt
# ates   tuns     tautness
# el   ta     teal
# el   tas     teals
# em   ta     team
# em   tas     teams
# er   ta     tear
# err   tae     tearer
# era   tags     teargas
# er   tas     tears
# es   ta     teas
# es   tae     tease
# ess   tae     teases
# et   ta     teat
# et   tas     teats
# ern   tree     terrene
# erns   tree     terrenes
# er   try     terry
# ess   tret     tersest
# he   ta     thae
# him   tar     thairm
# him   tars     thairms
# hi   ten     thein
# hie   ten     theine
# hie   tens     theines
# his   ten     theins
# hoe   term     theorem
# hoes   term     theorems
# ho   ti     thio
# ho   til     thiol
# huh   tog     though
# hot   tray     throaty
# od   ta     toad
# od   tas     toads
# os   tat     toast
# old   tie     toiled
# old   toe     tooled
# om   to     toom
# on   to     toon
# ras   ted     treads
# re   ted     treed
# ras   til     trials
# ree   tin     triene
# ree   tins     trienes
# res   tin     triens
# rets   tine     trientes
# re   tis     tries
# roe   tilt     triolet
# roes   tilt     triolets
# roe   tis     triose
# rue   tin     triune
# rue   tins     triunes
# rue   top     troupe
# rue   tops     troupes
# rat   tun     truant
# rat   tuns     truants
# rees   tuns     trueness
# rig   tun     truing
# us   ti     tuis
# we   ta     twae
# we   tas     twaes
# wis   tan     twains
# we   ted     tweed
# we   ten     tween
# wry   til     twirly
# bey   uit     ubiety
# la   un     ulna
# la   uns     ulnas
# net   urn     unrent
# no   ut     unto
# pep   uke     upkeep
# pep   ukes     upkeeps
# per   uta     uptear
# per   utas     uptears
# anes   vins     vainness
# ar   vis     vairs
# el   vas     veals
# eld   vie     veiled
# el   vis     veils
# end   vie     veined
# en   vis     veins
# odd   vie     voided
# odes   vins     voidness
# od   vis     voids
# as   we     waes
# an   wis     wains
# ar   wis     wairs
# as   wit     waist
# ass   wit     waists
# at   wis     waits
# at   wry     warty
# ekes   wans     weakness
# el   wad     weald
# els   wad     wealds
# el   was     weals
# end   wae     weaned
# en   was     weans
# err   wae     wearer
# err   waes     wearers
# ere   wair     wearier
# er   was     wears
# er   way     weary
# el   we     weel
# en   we     ween
# end   wee     weened
# er   we     weer
# es   we     wees
# es   wet     weest
# et   we     weet
# ewe   wee     weewee
# ewe   weed     weeweed
# ewe   wees     weewees
# erns   wides     weirdness
# eros   wide     weirdoes
# er   wis     weirs
# ha   wet     wheat
# has   wet     wheats
# he   we     whee
# he   wen     wheen
# hes   wen     wheens
# ha   wo     whoa
# ha   wos     whoas
# ho   wop     whoop
# odd   wae     woaded
# od   was     woads
# ons   wees     woeness
# os   we     woes
# od   wo     wood
# odd   woe     wooded
# od   wos     woods
# of   wo     woof
# of   wos     woofs
# old   woe     wooled
# op   wos     woops
# os   wo     woos
# od   wry     wordy
# om   wry     wormy
# or   wry     worry
# on   wud     wound
# ons   wud     wounds
# rah   wet     wreath
# rah   wets     wreaths
# re   wis     wries
# ret   wis     wriest
# ar   yid     yaird
# ars   yid     yairds
# eh   ya     yeah
# en   ya     yean
# er   ya     year
# es   ya     yeas
# un   ya     yuan

# %%
def husuo():
#     a=[]
    t=read_words()
    for s in t:
        s1=[]
        s2=[]
        s3=[]
        for i in range(len(s)):
            
            if i%3==0:
                s1.append(s[i])
            elif i%3==1:
                s2.append(s[i])
            else:
                s3.append(s[i])
        word1=''.join(s1)
        word2=''.join(s2)
        word3=''.join(s3)
        if find_lt(t,word1) and find_lt(t,word2) and find_lt(t,word3):
            print(word1+'   '+word2 +'     '+word3+'      '+s)
#     return a
husuo()
# Out:
# ace   bus     as      abacuses
# ale   bo     an      abalone
# ale   bos     an      abalones
# as   be     ad      abased
# as   be     ar      abaser
# ass   be     ar      abasers
# as   be     as      abases
# at   be     ad      abated
# at   be     ar      abater
# at   be     as      abates
# at   bi     as      abatis
# ate   bis     as      abatises
# at   bo     ar      abator
# ad   be     id      abided
# ad   be     is      abides
# ad   be     od      aboded
# ad   be     os      abodes
# am   ba     os      abomas
# ama   ba     os      abomasa
# ama   bal     os      abomasal
# ami   ba     os      abomasi
# amu   bas     os      abomasus
# ama   bit     one      abominate
# amas   bit     one      abominates
# as   be     us      abuses
# are   cad     et      acerated
# ate   cad     et      acetated
# ate   cos     en      acetones
# ana   do     em      adenoma
# ana   dos     em      adenomas
# ape   do     is      adipose
# ape   dos     is      adiposes
# ar   de     od      adored
# ar   de     or      adorer
# ars   de     or      adorers
# ar   de     os      adores
# ale   da     ut      adulate
# ale   dad     ut      adulated
# ai   el     de      aedile
# ais   el     de      aediles
# ai   en     de      aedine
# aa   et     re      aerate
# aas   et     re      aerates
# ate   gad     it      agitated
# ate   gas     it      agitates
# ane   gid     os      agonised
# ais   ins     re      airiness
# am   lo     as      alamos
# an   li     an      alanin
# ane   li     an      alanine
# ane   lis     an      alanines
# awe   li     ef      alewife
# axe   li     en      alexine
# axe   lis     en      alexines
# ad   la     id      alidad
# ads   la     id      alidads
# ah   la     os      alohas
# ars   lum     ti      altruism
# ars   lum     tis      altruisms
# am   li     un      alumin
# ama   li     un      alumina
# ama   lis     un      aluminas
# ane   li     ut      alunite
# ane   lis     ut      alunites
# ana   mi     at      amanita
# ana   mis     at      amanitas
# ars   mi     be      ambries
# any   mi     et      amenity
# ad   me     is      amides
# ad   mi     in      amidin
# ads   mi     in      amidins
# an   me     is      amines
# any   mi     it      aminity
# are   ma     it      amirate
# are   mas     it      amirates
# art   mi     os      amorist
# art   mis     os      amorists
# as   me     us      amuses
# ate   na     as      anatase
# am   na     is      animas
# am   nu     is      animus
# ar   na     un      anuran
# ars   na     un      anurans
# ais   no     xu      anxious
# ate   pi     at      apatite
# ate   pis     at      apatites
# ale   pus     on      apolunes
# ami   pis     ox      apomixis
# arc   poh     pa      approach
# and   re     ai      araneid
# and   res     ai      araneids
# at   re     es      aretes
# as   re     in      arisen
# as   re     is      arises
# ane   si     in      asinine
# ala   ta     ay      atalaya
# ala   tas     ay      atalayas
# am   ta     an      ataman
# aid   ut     de      audited
# air   ut     do      auditor
# air   uts     do      auditors
# aa   ut     re      aurate
# big   ane     da      badinage
# big   ane     dad      badinaged
# ba   at     la      balata
# bas   at     la      balatas
# ba   an     na      banana
# bas   an     na      bananas
# bi   at     re      barite
# bis   at     re      barites
# bog   ane     ras      baronages
# bot   an     re      baronet
# by   at     re      baryte
# bys   at     re      barytes
# ben   ale     si      baseline
# ben   ale     sis      baselines
# bot   an     ye      bayonet
# ben   em     da      bedeman
# ben   em     de      bedemen
# bel   eve     did      bedeviled
# ba   et     ma      bemata
# bi   er     me      bemire
# bid   er     me      bemired
# bis   er     me      bemires
# bin   erg     mi      bemiring
# bid   ex     me      bemixed
# bis   ex     me      bemixes
# bud   es     me      bemused
# bus   es     me      bemuses
# bin   es     no      benison
# bin   ess     no      benisons
# ba   et     re      berate
# bad   et     re      berated
# bas   et     re      berates
# bi   em     re      berime
# bid   em     re      berimed
# bis   em     re      berimes
# beg   ere     vas      beverages
# ba   er     we      beware
# bad   er     we      bewared
# bas   er     we      bewares
# bot   ire     fa      biforate
# bel   it     ma      bimetal
# bel   its     ma      bimetals
# bel   id     pa      bipedal
# beg   li     un      blueing
# beg   lis     un      blueings
# be   or     lo      bolero
# ba   on     re      borane
# bas   on     re      boranes
# bas   ox     re      boraxes
# bi   od     re      boride
# bis   od     re      borides
# bas   one     ti      botanise
# bas   one     tis      botanises
# bed   or     we      bowered
# by   re     ad      brayed
# by   re     ar      brayer
# bys   re     ar      brayers
# bal   un     to      butanol
# bal   uns     to      butanols
# cat   ar     be      cabaret
# cat   ars     be      cabarets
# cog   ate     ba      cabotage
# cog   ate     bas      cabotages
# car   am     la      calamar
# cats   ami     lie      calamities
# cee   ar     ma      camerae
# cut   ale     na      canulate
# coz   ane     pi      caponize
# coz   ane     pis      caponizes
# col   ar     pa      caporal
# col   ars     pa      caporals
# cos   at     pe      capotes
# can   aga     ras      caraganas
# can   ave     rad      caravaned
# cod   am     re      caromed
# con   ate     re      carotene
# con   ate     res      carotenes
# car   ama     tan      catamaran
# cars   ama     tan      catamarans
# cee   an     ta      catenae
# cess   ars     tee      cateresses
# cee   ers     li      celeries
# cop   eth     na      cenotaph
# cad   et     re      cerated
# cry   hi     at      charity
# cry   li     at      clarity
# cry   li     es      clerisy
# cat   obe     hid      cohabited
# cot   obe     ha      cohobate
# cot   obe     had      cohobated
# cot   obe     has      cohobates
# cos   one     li      colonise
# cos   one     lid      colonised
# cos   one     lis      colonises
# coz   one     li      colonize
# coz   one     lid      colonized
# coz   one     lis      colonizes
# con   ort     la      colorant
# con   ort     las      colorants
# cos   ort     li      colorist
# cos   ort     lis      colorists
# cee   ods     mi      comedies
# can   ort     pe      coparent
# can   ort     pes      coparents
# cut   ole     pa      copulate
# cut   ole     pad      copulated
# cut   ole     pas      copulates
# col   on     re      coronel
# col   ons     re      coronels
# cot   on     re      coronet
# cot   ons     re      coronets
# cee   or     ti      coterie
# cee   ors     ti      coteries
# cess   uns     tee      cutenesses
# day   aba     hi      dahabiya
# day   aba     his      dahabiyas
# da   as     li      dalasi
# dol   as     me      damosel
# dol   ass     me      damosels
# dad   ami     tea      datamedia
# den   ale     ti      dateline
# den   ale     tis      datelines
# duc   ar     ti      daturic
# did   er     ae      deaired
# din   erg     ai      deairing
# da   es     be      debase
# dad   es     be      debased
# da   et     be      debate
# dad   et     be      debated
# did   et     be      debited
# do   en     be      debone
# dor   en     be      deboner
# dor   ens     be      deboners
# dos   en     be      debones
# don   eng     bi      deboning
# dud   et     be      debuted
# dit   eme     cad      decimated
# dot   ere     cad      decorated
# dry   ef     el      deerfly
# dit   em     li      delimit
# dit   eme     lid      delimited
# dit   ems     li      delimits
# dun   egg     li      deluging
# dip   er     me      demirep
# dip   ers     me      demireps
# did   es     me      demised
# dos   ens     me      demoness
# doc   en     mi      demonic
# dos   es     me      demoses
# do   et     me      demote
# dos   et     me      demotes
# doc   et     mi      demotic
# do   en     pe      depone
# dos   en     pe      depones
# don   eng     pi      deponing
# dol   es     pa      deposal
# dol   ess     pa      deposals
# do   es     pe      depose
# dor   es     pe      deposer
# dor   ess     pe      deposers
# dos   es     pe      deposes
# dot   es     pi      deposit
# dot   ess     pi      deposits
# dud   et     pe      deputed
# dit   eve     ras      derivates
# din   erg     si      desiring
# dad   ex     we      dewaxed
# die   its     mi      dimities
# doc   id     pi      dipodic
# doe   ids     pi      dipodies
# des   ins     re      direness
# duo   inn     si      disunion
# duo   inn     sis      disunions
# dit   one     ma      dominate
# dit   one     mad      dominated
# dit   one     mas      dominates
# die   on     mi      dominie
# die   ons     mi      dominies
# els   ait     re      earliest
# ens   bi     oe      ebonies
# eta   col     on      ecotonal
# em   da     es      edemas
# el   de     is      ediles
# et   de     id      edited
# em   li     es      elemis
# eve   la     et      elevate
# eve   lad     et      elevated
# eve   las     et      elevates
# er   mu     be      embrue
# ers   mu     be      embrues
# ern   mug     bi      embruing
# er   my     bo      embryo
# ern   my     bo      embryon
# ers   my     bo      embryos
# era   mi     et      emerita
# es   me     es      emeses
# es   mi     es      emesis
# et   mi     en      emetin
# ere   ma     it      emirate
# ere   mas     it      emirates
# et   me     od      emoted
# et   me     or      emoter
# et   me     os      emotes
# em   no     ar      enamor
# eme   nod     ar      enamored
# ems   no     ar      enamors
# em   na     es      enemas
# ern   nae     gid      engrained
# ern   na     ti      entrain
# es   pe     os      eposes
# es   re     ad      erased
# es   re     ar      eraser
# ess   re     ar      erasers
# es   re     as      erases
# es   re     os      eroses
# ere   si     en      eserine
# ere   sis     en      eserines
# em   ti     an      etamin
# eme   ti     an      etamine
# eme   tis     an      etamines
# ems   ti     an      etamins
# eel   un     go      eugenol
# eel   uns     go      eugenols
# eses   vins     ave      evasiveness
# eng   vis     en      evenings
# eme   xi     an      examine
# eme   xis     an      examines
# es   ye     as      eyases
# els   ye     es      eyeless
# el   ye     et      eyelet
# els   ye     et      eyelets
# ewe   yar     et      eyewater
# flu   ai     ba      fabliau
# fed   aga     na      fanegada
# fas   alt     ti      fatalist
# fas   alt     tis      fatalists
# fet   ere     da      federate
# fet   ere     dad      federated
# foe   ens     li      felonies
# fa   el     me      female
# fas   el     me      females
# fie   en     mi      feminie
# fud   el     re      feruled
# fet   era     ti      feterita
# fet   era     tis      feteritas
# fa   er     us      feuars
# fez   ire     bi      fiberize
# fez   ire     bid      fiberized
# fez   ire     bis      fiberizes
# fid   ice     li      filicide
# fid   ice     lis      filicides
# fess   ins     nee      finenesses
# fie   its     xi      fixities
# fly   oe     or      foolery
# fan   om     re      foramen
# fan   oms     re      foramens
# fad   oy     re      forayed
# far   oy     re      forayer
# fed   obe     rod      foreboded
# feds   obi     roe      forebodies
# fet   ode     rad      foredated
# fet   ode     ras      foredates
# fee   oft     re      forefeet
# fen   old     ras      forelands
# fen   om     re      foremen
# fer   opt     ras      foreparts
# fee   os     re      foresee
# fer   own     ras      forewarns
# fa   ut     go      fugato
# fas   ut     go      fugatos
# fa   un     re      furane
# fas   un     re      furanes
# gan   are     de      gadarene
# get   ane     li      galenite
# get   ane     lis      galenites
# god   ape     la      galopade
# god   ape     las      galopades
# go   at     re      garote
# god   at     re      garoted
# gey   aw     ta      gateway
# gan   et     li      gelatin
# go   et     me      gemote
# gel   er     na      general
# gel   ers     na      generals
# get   ere     na      generate
# gan   it     go      gigaton
# gan   its     go      gigatons
# gas   in     to      gitanos
# go   on     by      gobony
# gel   or     ma      gomeral
# gel   ors     ma      gomerals
# gel   or     me      gomerel
# gel   ors     me      gomerels
# gel   or     mi      gomeril
# gel   ors     mi      gomerils
# gal   od     na      gonadal
# gor   ope     no      gonopore
# gor   ope     nos      gonopores
# git   oe     os      gooiest
# gad   on     we      gowaned
# hin   at     ba      habitan
# hit   at     ba      habitat
# hid   at     be      habited
# hid   ate     bus      habitudes
# him   ad     lo      halidom
# him   ads     lo      halidoms
# ha   at     me      hamate
# has   at     me      hamates
# hut   ale     ma      hamulate
# hun   am     na      hanuman
# he   er     to      hetero
# hes   er     to      heteros
# hiss   ons     lee      holinesses
# hen   old     ma      homeland
# hen   old     mas      homelands
# hens   ole     mis      homeliness
# het   ose     mi      homesite
# het   ose     mis      homesites
# hid   oca     mil      homicidal
# his   ons     me      hominess
# hid   on     mi      hominid
# hid   ons     mi      hominids
# hie   ons     mi      hominies
# hin   one     mi      hominine
# hi   on     my      hominy
# he   oy     os      hooeys
# ha   un     me      humane
# ha   ut     me      humate
# has   ut     me      humates
# is   be     is      ibises
# id   me     is      imides
# in   me     is      imines
# id   re     as      irades
# it   re     ar      irater
# id   re     is      irides
# is   re     id      irised
# is   re     is      irises
# in   re     od      ironed
# in   re     or      ironer
# ins   re     or      ironers
# in   re     os      irones
# it   si     an      isatin
# its   si     an      isatins
# ire   ta     et      iterate
# ire   tad     et      iterated
# ire   tas     et      iterates
# id   xi     od      ixodid
# ids   xi     od      ixodids
# jut   ale     cad      jaculated
# jee   ars     pi      japeries
# ka   ay     ba      kabaya
# kas   ay     ba      kabayas
# kef   awe     li      kalewife
# kat   ace     mi      kamacite
# kat   ace     mis      kamacites
# ka   at     re      karate
# kas   at     re      karates
# kos   es     ti      ketosis
# la   ar     ba      labara
# lot   are     bi      laborite
# lot   are     bis      laborites
# let   are     cad      lacerated
# led   an     de      ladened
# li   an     do      ladino
# lis   an     do      ladinos
# li   aa     me      lamiae
# li   an     ma      lamina
# lie   an     ma      laminae
# lis   an     ma      laminas
# lit   ane     ma      laminate
# lit   ane     mad      laminated
# lit   ane     mas      laminates
# lis   ad     pe      lapides
# lis   as     pe      lapises
# li   an     re      larine
# led   ar     ta      laterad
# let   are     ti      laterite
# let   are     tis      laterites
# lits   ani     tie      latinities
# lit   any     ti      latinity
# la   an     us      lauans
# li   an     we      lawine
# lis   an     we      lawines
# lay   aw     ya      layaway
# leg   are     ya      layerage
# led   ar     ye      layered
# la   et     go      legato
# lar   et     go      legator
# las   et     go      legatos
# lime   eta     git      legitimate
# lo   en     my      lemony
# leg   ere     vas      leverages
# lit   ere     vas      levirates
# lis   es     we      lewises
# li   is     ae      liaise
# lid   is     ae      liaised
# lis   is     ae      liaises
# let   ire     ba      liberate
# let   ire     bad      liberated
# let   ire     bas      liberates
# li   id     bo      libido
# lis   id     bo      libidos
# li   in     ma      limina
# lis   ins     me      liminess
# lid   it     me      limited
# lid   its     me      limiteds
# lis   it     me      limites
# la   is     pe      lipase
# las   is     pe      lipases
# li   id     pe      lipide
# lis   id     pe      lipides
# let   ire     ta      literate
# let   ire     tas      literates
# less   ins     vee      livenesses
# less   ons     nee      lonenesses
# li   oe     os      looies
# lis   os     re      lorises
# li   oe     us      louies
# lens   ole     vis      loveliness
# led   or     we      lowered
# li   un     ma      lumina
# lar   un     pa      lupanar
# lar   uns     pa      lupanars
# li   un     pe      lupine
# lis   un     pe      lupines
# met   are     cad      macerated
# mut   ale     cad      maculated
# ma   am     de      madame
# mas   am     de      madames
# mu   ar     do      maduro
# mus   ar     do      maduros
# moa   an     hi      mahonia
# mu   at     ka      makuta
# mae   ads     li      maladies
# mor   ad     lo      malodor
# mor   ads     lo      malodors
# ma   an     na      manana
# mas   an     na      mananas
# mir   ace     nu      manicure
# mir   ace     nus      manicures
# mi   at     no      manito
# mis   at     no      manitos
# mi   at     nu      manitu
# mis   at     nu      manitus
# mid   ane     rad      marinaded
# mid   ane     ras      marinades
# mir   ana     ras      marinaras
# mi   an     re      marine
# mir   an     re      mariner
# mis   an     re      marines
# mar   ad     to      matador
# mar   ads     to      matadors
# met   ale     to      matelote
# mil   an     ta      matinal
# mut   are     ta      maturate
# mut   are     tad      maturated
# mut   are     tas      maturates
# mim   am     xu      maximum
# mol   ar     ya      mayoral
# mol   art     yay      mayoralty
# mad   el     de      medaled
# mu   es     da      medusa
# mun   es     da      medusan
# mun   ess     da      medusans
# mus   es     da      medusas
# man   et     go      megaton
# man   eme     li      melamine
# man   eme     lis      melamines
# mac   en     li      melanic
# mac   ens     li      melanics
# man   en     li      melanin
# man   ens     li      melanins
# mis   es     re      merises
# mid   et     re      merited
# men   erg     ti      metering
# ma   id     li      miladi
# mae   ids     li      miladies
# mas   id     li      miladis
# mis   ins     re      miriness
# miss   ins     ree      mirinesses
# met   id     si      misedit
# met   ids     si      misedits
# mid   ice     ti      miticide
# mid   ice     tis      miticides
# mis   ole     bi      mobilise
# mis   ole     bid      mobilised
# mis   ole     bis      mobilises
# met   ore     da      moderate
# met   ore     dad      moderated
# mut   ole     da      modulate
# mut   ole     dad      modulated
# mus   os     me      momuses
# mod   ope     no      monopode
# mod   ope     nos      monopodes
# mol   ope     no      monopole
# mol   ope     nos      monopoles
# mom   ose     no      monosome
# mom   ose     nos      monosomes
# mun   or     no      monuron
# mun   ors     no      monurons
# mas   ole     rid      moralised
# mons   ose     res      moroseness
# me   ut     la      muleta
# mi   un     re      murine
# mis   un     re      murines
# mess   uns     tee      mutenesses
# nor   aby     be      nabobery
# nil   ar     da      nadiral
# na   ad     is      naiads
# nee   ars     pi      naperies
# nit   age     vas      navigates
# nu   el     ba      nebula
# nus   el     ba      nebulas
# nu   el     be      nebule
# nu   el     by      nebuly
# ness   ins     cee      nicenesses
# nus   is     de      niduses
# no   od     by      nobody
# no   os     de      nodose
# nus   ole     do      nodulose
# nil   on     ma      nominal
# nil   ons     ma      nominals
# nit   one     ma      nominate
# nit   one     mad      nominated
# nit   one     mas      nominates
# nae   ors     ti      notaries
# na   od     ye      noyade
# ness   uns     dee      nudenesses
# ole   bi     es      obelise
# ole   bid     es      obelised
# ole   bis     es      obelises
# oy   be     er      obeyer
# ort   da     on      odorant
# or   de     od      odored
# oe   em     da      oedema
# oes   em     da      oedemas
# old   foe     fad      offloaded
# of   li     en      olefin
# os   mu     am      omasum
# ons   nee     ess      onenesses
# ole   pi     an      opaline
# ole   pis     an      opalines
# on   pe     er      opener
# ons   pe     er      openers
# ort   pa     en      operant
# ort   pas     en      operants
# or   pa     es      operas
# ore   pa     et      operate
# ore   pad     et      operated
# ore   pas     et      operates
# ort   pea     et      operetta
# on   pe     id      opined
# on   pe     is      opines
# os   pe     us      opuses
# obi   rad     it      oribatid
# obi   rad     its      oribatids
# oped   urn     tee      outpreened
# ort   vee     ear      overeater
# orts   vee     ear      overeaters
# ole   vas     ut      ovulates
# ole   xis     as      oxalises
# ode   xi     is      oxidise
# ode   xis     is      oxidises
# pa   an     es      paeans
# pas   ane     gid      paganised
# pit   ane     gad      paginated
# pit   ane     gas      paginates
# pan   ad     li      paladin
# pan   ads     li      paladins
# pal   at     la      palatal
# pan   ate     li      palatine
# pan   ate     lis      palatines
# par   ave     led      palavered
# pet   at     lo      paletot
# pes   awe     li      palewise
# pul   ad     la      paludal
# pa   ad     na      panada
# pas   ad     na      panadas
# pa   am     na      panama
# pas   am     na      panamas
# pa   ay     pa      papaya
# pan   ay     pa      papayan
# pas   ay     pa      papayas
# ped   ar     pe      papered
# per   ar     pe      paperer
# per   ars     pe      paperers
# pa   ad     re      parade
# pad   ad     re      paraded
# par   ad     re      parader
# par   ads     re      paraders
# pas   ad     re      parades
# pan   age     rod      paragoned
# pan   ave     ras      paravanes
# pes   as     re      pareses
# pis   as     re      parises
# pus   ar     re      parures
# par   am     ta      patamar
# pi   an     ta      patina
# pie   an     ta      patinae
# pis   an     ta      patinas
# pad   el     de      pedaled
# pa   et     de      pedate
# pen   ere     li      pelerine
# pen   ere     lis      pelerines
# pic   et     li      pelitic
# pia   en     re      perinea
# pot   ere     rad      perorated
# pot   ere     ras      perorates
# pud   es     re      perused
# pur   es     re      peruser
# pur   ess     re      perusers
# pus   es     re      peruses
# pas   es     to      petasos
# pen   erg     ti      petering
# pa   it     na      pinata
# pas   it     na      pinatas
# pen   ice     no      pinecone
# pen   ice     nos      pinecones
# pep   is     na      pinesap
# pe   it     na      pineta
# pen   ire     pi      piperine
# pen   ire     pis      piperines
# pa   it     re      pirate
# pad   it     re      pirated
# pas   it     re      pirates
# pas   ore     li      polarise
# pas   ore     lid      polarised
# pas   ore     lis      polarises
# pan   or     lo      polaron
# pan   ors     lo      polarons
# pa   od     me      pomade
# pad   od     me      pomaded
# pas   od     me      pomades
# pee   ors     pi      poperies
# ped   oy     pe      popeyed
# put   ole     pa      populate
# put   ole     pad      populated
# put   ole     pas      populates
# pac   om     ti      potamic
# ped   or     we      powered
# psi   ran     egg      presaging
# psi   roc     od      prosodic
# psi   roe     ods      prosodies
# piss   uns     nee      puninesses
# pa   ut     pe      pupate
# pad   ut     pe      pupated
# pas   ut     pe      pupates
# pes   uns     re      pureness
# pi   un     re      purine
# pis   un     re      purines
# ras   at     bo      rabatos
# rat   at     ta      ratatat
# rid   ace     ti      raticide
# rid   ace     tis      raticides
# rad   et     be      rebated
# ras   et     be      rebates
# ras   et     bo      rebatos
# rue   ers     bi      reburies
# rad   et     de      redated
# ras   et     de      redates
# read   eft     dee      redefeated
# rid   eve     did      redivided
# ras   er     en      reearns
# rid   er     he      rehired
# rin   erg     hi      rehiring
# ran   ex     li      relaxin
# rin   eng     li      relining
# run   eme     li      relumine
# run   eme     lid      relumined
# run   eme     lis      relumines
# rid   es     me      remised
# rid   ex     me      remixed
# rod   er     mi      remorid
# red   ego     na      renegado
# reds   ego     nae      renegadoes
# rot   eve     na      renovate
# rid   el     oe      reoiled
# rid   en     pe      repined
# rin   eng     pi      repining
# rod   es     pe      reposed
# rot   es     pi      reposit
# rot   ess     pi      reposits
# rin   es     re      rerisen
# rin   eng     si      resining
# rin   erg     ti      retiring
# run   eng     ti      retuning
# ran   eke     wed      rewakened
# rad   ex     we      rewaxed
# ras   ex     we      rewaxes
# rid   er     we      rewired
# red   in     pe      ripened
# res   ins     pe      ripeness
# ree   ors     pi      roperies
# ree   ors     si      roseries
# re   on     us      rouens
# ras   ut     bo      rubatos
# res   uns     de      rudeness
# si   an     be      sabine
# sis   an     be      sabines
# sin   ar     do      sadiron
# sin   ars     do      sadirons
# sae   ars     li      salaries
# sin   ace     li      salicine
# sin   ace     lis      salicines
# si   an     la      salina
# sis   an     la      salinas
# sits   ani     lie      salinities
# sit   any     li      salinity
# sit   ave     la      salivate
# sit   ave     lad      salivated
# sit   ave     las      salivates
# sau   arm     mi      samarium
# sau   arm     mis      samariums
# sin   as     me      samisen
# sin   ass     me      samisens
# si   at     me      samite
# sis   at     me      samites
# sit   ate     na      sanitate
# son   an     pi      saponin
# son   ane     pi      saponine
# son   ane     pis      saponines
# sot   ane     pi      saponite
# sot   ane     pis      saponites
# so   at     pa      sapota
# sos   at     pa      sapotas
# so   ad     re      sarode
# sos   ad     re      sarodes
# sac   an     ti      satanic
# sic   ar     ti      satiric
# sis   are     ti      satirise
# sis   are     tis      satirises
# sis   art     ti      satirist
# sis   art     tis      satirists
# so   ar     ti      satori
# sos   ar     ti      satoris
# sun   art     ta      saturant
# sun   art     tas      saturants
# sal   ate     xi      saxatile
# sac   es     bi      sebasic
# sad   et     de      sedated
# si   el     de      sedile
# sec   en     li      selenic
# sac   et     mi      sematic
# sit   ef     mi      semifit
# sit   em     ma      semimat
# sit   eme     mu      semimute
# si   en     ma      semina
# sir   en     ma      seminar
# sir   ens     ma      seminars
# sis   es     me      semises
# so   er     na      senora
# sos   er     na      senoras
# sad   el     pe      sepaled
# sat   ere     pa      separate
# sat   ere     pad      separated
# sat   ere     pas      separates
# ser   en     re      serener
# si   en     re      serine
# sis   en     re      serines
# so   he     od      shooed
# sea   is     li      silesia
# sit   ice     la      silicate
# sit   ice     las      silicates
# sin   ice     lo      silicone
# sir   ill     may      similarly
# sir   it     ma      simitar
# sir   its     ma      simitars
# so   in     my      simony
# ser   ice     nu      sinecure
# ser   ice     nus      sinecures
# ser   or     be      soberer
# sen   om     ka      sokeman
# si   od     li      solidi
# sots   ons     lee      solonetses
# son   ort     na      sonorant
# sou   ors     no      sonorous
# sot   ore     ras      sororates
# sos   os     re      soroses
# sh   pe     ae      spahee
# sh   pi     as      spahis
# sri   pac     od      sporadic
# ski   tea     os      stokesia
# si   ta     re      striae
# sim   ut     be      subitem
# sim   uts     be      subitems
# si   ut     bo      subito
# si   un     pe      supine
# sis   un     pe      supines
# tad   an     bi      tabanid
# tat   ar     be      tabaret
# tat   ars     be      tabarets
# ted   ar     be      tabered
# tod   ar     be      tabored
# tor   ar     be      taborer
# tor   ars     be      taborers
# tot   ar     be      taboret
# tot   ars     be      taborets
# ton   ar     bi      taborin
# ton   are     bi      taborine
# ton   are     bis      taborines
# ton   ars     bi      taborins
# tut   ale     ba      tabulate
# tut   ale     bad      tabulated
# tut   ale     bas      tabulates
# tao   ar     ma      tamarao
# tao   ars     ma      tamaraos
# tau   ar     ma      tamarau
# tau   ars     ma      tamaraus
# tan   ar     mi      tamarin
# tan   ars     mi      tamarins
# tas   ark     mi      tamarisk
# tas   ark     mis      tamarisks
# tis   as     me      tamises
# tar   ado     pe      tapadero
# tar   ado     pes      tapaderos
# ten   ale     pi      tapeline
# ten   ale     pis      tapelines
# ted   ar     pe      tapered
# tis   as     pe      tapises
# ta   am     ti      tatami
# tas   am     ti      tatamis
# tic   at     xi      taxitic
# tan   em     lo      telamon
# ten   em     la      teleman
# ten   er     la      teleran
# ten   ers     la      telerans
# tee   efs     pi      tepefies
# tae   ens     ti      tetanies
# tug   hi     on      thouing
# tis   ins     de      tidiness
# ta   id     re      tirade
# tas   id     re      tirades
# tass   ins     tee      titanesses
# tau   ins     to      titanous
# ten   ort     la      tolerant
# tin   od     li      tolidin
# tin   ode     li      tolidine
# tin   ode     lis      tolidines
# tin   ods     li      tolidins
# to   os     re      torose
# tas   ole     ti      totalise
# tas   ole     tis      totalises
# ted   or     we      towered
# tee   ors     wit      toweriest
# tea   om     xi      toxemia
# tea   oms     xi      toxemias
# ta   ut     be      tubate
# urd   na     bi      unbraid
# urd   nae     bid      unbraided
# up   no     id      unipod
# ups   no     id      unipods
# us   no     in      unison
# us   pe     as      upases
# urd   pa     bi      upbraid
# urd   pas     bi      upbraids
# urd   pi     de      updried
# us   re     as      urases
# ut   re     as      urates
# ut   re     er      ureter
# uts   re     er      ureters
# un   re     is      urines
# us   re     us      uruses
# vis   an     he      vahines
# vet   are     la      valerate
# vet   are     las      valerates
# vau   ads     no      vanadous
# vet   ere     na      venerate
# vin   es     no      venison
# vin   ess     no      venisons
# vie   ifs     li      vilifies
# vee   ors     li      voleries
# vas   ort     ti      votarist
# vas   ort     tis      votarists
# wis   an     he      wahines
# wis   at     pi      wapitis
# who   arm     so      washroom
# who   arm     sos      washrooms
# wee   ars     tit      wateriest
# wed   el     de      wedeled
# wed   in     de      widened
# wiss   ins     lee      wilinesses
# wis   ins     re      wiriness
# wiss   ins     ree      wirinesses
# wad   on     me      womaned
# was   one     mi      womanise
# was   one     mid      womanised
# was   one     mis      womanises
# we   or     ma      womera
# we   or     os      wooers

# %%
from inlist import *


def interlock(word_list, word):
    """Checks whether a word can be split into two interlocked words.

    word_list: list of strings
    word: string
    """
    evens = word[::2]
    odds = word[1::2]
    return in_bisect(word_list, evens) and in_bisect(word_list, odds) 
        

def interlock_general(word_list, word, n=3):
    """Checks whether a word can be split into n interlocked words.

    word_list: list of strings
    word: string
    n: number of interleaved words
    """
    for i in range(n):
        inter = word[i::n]
        if not in_bisect(word_list, inter):
            return False
    return True
        

if __name__ == '__main__':
    word_list = make_word_list()
    
    for word in word_list:
        if interlock(word_list, word):
            print(word, word[::2], word[1::2])


#    for word in word_list:
#        if interlock_general(word_list, word, 3):
#            print (word, word[0::3], word[1::3], word[2::3])

# %%
'hello'[::2]
# Out:
# 'hlo'
